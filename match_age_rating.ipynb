# %%
# %pip install --upgrade openai

# %% [markdown]
# ### Match the closest file name video with the Database from CommonSense that already hold age ratings

# %%
import os
import json
import pandas as pd
import openai
from dotenv import load_dotenv

# Load OpenAI API key from .env file
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

# Assign the actual API key from environment variable
openai.api_key = api_key

# Path to your Excel file
excel_path = '/Users/santiagowon/Dropbox/Santiago/01. Maestria/Tesis/01_Scrapping_List/DB_Age_OnlyAnalysedVideos.xlsx'

# Load the Excel file
excel_data = pd.read_excel(excel_path)

# Extract relevant columns (adjust the column names as needed)
excel_data = excel_data[['Title', 'Age Rating', 'Age']]  # Adjust as per your actual column names

# Path to the directory containing the JSON files
json_dir = '/Users/santiagowon/Dropbox/Santiago/01. Maestria/Tesis/11_Project_Analysed_DB/1 Done'

# List to store show names from JSON files
json_shows = []

# Iterate through each folder (ignoring non-directory files like .DS_Store)
for show_folder in os.listdir(json_dir):
    folder_path = os.path.join(json_dir, show_folder)
    
    if os.path.isdir(folder_path):  # Only process if it's a directory
        for file_name in os.listdir(folder_path):
            if file_name.endswith('_stats.json'):
                json_file_path = os.path.join(folder_path, file_name)
                with open(json_file_path, 'r') as f:
                    data = json.load(f)
                    json_shows.append(data['video_title'])

# Convert the JSON show names into a DataFrame
json_shows_df = pd.DataFrame(json_shows, columns=['video_title'])

# Function to extract the title from the OpenAI response
def extract_title_from_response(response_content):
    # Assuming the matched title is after "The closest matching title to 'X' is 'Y'."
    return response_content.split("'")[-2] if "'" in response_content else response_content

# Function to use OpenAI API to find closest match (with batching)
def find_closest_match(json_show, excel_titles, batch_size=50):
    matched_title = None
    
    # Break the list of titles into batches to avoid exceeding token limit
    for i in range(0, len(excel_titles), batch_size):
        title_batch = excel_titles[i:i+batch_size]  # Take a batch of titles
        
        prompt = f"Match the following TV show title: '{json_show}' to one of the following: {', '.join(title_batch)}. Return the closest matching title."
        
        response = openai.chat.completions.create(
            model="gpt-4",
            messages=[
                {"role": "system", "content": "You are an assistant that matches TV show titles."},
                {"role": "user", "content": prompt}
            ]
        )
        
        # Extract the matching title from the response
        if response and response.choices:
            response_content = response.choices[0].message.content.strip()
            matched_title = extract_title_from_response(response_content)
        
        # Debug: Print the OpenAI API response
        print(f"OpenAI API Response for {json_show}: {response}")
        
        # If we find a match, return it
        if matched_title:
            return matched_title

    # If no match is found, return a default message or None
    return matched_title or "No Match Found"

# List to store matches
matched_shows = []

# Match each JSON show title with the Excel titles (using batching)
for json_show in json_shows:
    matched_title = find_closest_match(json_show, excel_data['Title'].tolist(), batch_size=50)  # Adjust batch_size if needed
    matched_shows.append({'json_show': json_show, 'matched_title': matched_title})

# Convert the results into a DataFrame
matched_df = pd.DataFrame(matched_shows)

# Normalize the case and remove extra spaces before merging
matched_df['matched_title'] = matched_df['matched_title'].str.lower().str.strip()
excel_data['Title'] = excel_data['Title'].str.lower().str.strip()

# Merge the matched shows with the Excel data to get age ratings
final_df = pd.merge(matched_df, excel_data, left_on='matched_title', right_on='Title')

# Now you have a DataFrame with JSON show titles and corresponding age ratings
print("Final DataFrame (After Merge with Excel):")
print(final_df)
# Out:
# OpenAI API Response for Molang: ChatCompletion(id='chatcmpl-A89uQi2AsKPCWdX33jIxCBY0W6l3e', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The closest matching title to 'Molang' is 'Molang'.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508078, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=14, prompt_tokens=179, total_tokens=193, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# OpenAI API Response for Duck_And_Goose: ChatCompletion(id='chatcmpl-A89uSzd21yCb7MwuVg6nRf3dZc4dq', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The closest matching title to 'Duck_And_Goose' is 'Duck & Goose'.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508080, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=19, prompt_tokens=182, total_tokens=201, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# OpenAI API Response for Digimon_Digital_Monsters: ChatCompletion(id='chatcmpl-A89uTwfHxeMXA5I0Su25foAVBUFN2', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The closest matching title to 'Digimon_Digital_Monsters' is 'Digimon: Digital Monsters'.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508081, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=22, prompt_tokens=184, total_tokens=206, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# OpenAI API Response for Tales_of_the_Jedi: ChatCompletion(id='chatcmpl-A89uVPGfeqiyymtiCH9DkIIBi3GxA', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="None of the given titles closely match to 'Tales_of_the_Jedi'. However, considering the genre, the closest might be 'Avatar: The Last Airbender' as it also involves elements of adventure and fantasy.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508083, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=45, prompt_tokens=183, total_tokens=228, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# OpenAI API Response for Mickey's_Mousekersize: ChatCompletion(id='chatcmpl-A89uZDDDq4HMhuQePMz8aAdnlc72C', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The closest matching title is 'Mickey's Mousekersize'.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508087, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=13, prompt_tokens=183, total_tokens=196, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# OpenAI API Response for Grizzy_and_the_Lemmings: ChatCompletion(id='chatcmpl-A89ubMQKEjp5URXBCXmzGHTyNY5L6', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The closest matching title to 'Grizzy_and_the_Lemmings' is 'Grizzy and the Lemmings'.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508089, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=24, prompt_tokens=184, total_tokens=208, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# OpenAI API Response for Shinchan: ChatCompletion(id='chatcmpl-A89udsMDr4Af9Qvj4dsX7aUFWzzoO', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="'Shinchan' does not have a direct match in the provided list. However, based on the fact it's an animated show originated in Asia, a potential close match could be 'Digimon: Digital Monsters' which is another Asian originated animated show. But this is a bit of a stretch since the show's content and style would be significantly different. Please provide more context or more show titles.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508091, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=80, prompt_tokens=180, total_tokens=260, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# OpenAI API Response for Polly_Pockets: ChatCompletion(id='chatcmpl-A89ujfJQURKMNpDupiJttsoHlDHnJ', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The closest matching title to 'Polly_Pockets' is 'Polly Pocket'.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508097, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=17, prompt_tokens=181, total_tokens=198, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# OpenAI API Response for Pat_The_Dog: ChatCompletion(id='chatcmpl-A89ulAla5K7YqPaKSxA8PzOdjZdNV', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The closest matching title to 'Pat_The_Dog' is 'Pat the Dog'.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508099, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=18, prompt_tokens=182, total_tokens=200, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# OpenAI API Response for Supernatural_Academy: ChatCompletion(id='chatcmpl-A89une6xqUt6qKdgYOZYmJPJyiFtH', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The closest matching title to 'Supernatural Academy' is 'Mysticons'.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508101, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=17, prompt_tokens=183, total_tokens=200, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# OpenAI API Response for The_Doc_McStuffins_Christmas_Special: ChatCompletion(id='chatcmpl-A89up9y29SYzT6G6TQyh49wbN2q3s', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The closest matching title is 'The Doc McStuffins Christmas Special'.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508103, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=14, prompt_tokens=189, total_tokens=203, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# OpenAI API Response for Mysticons: ChatCompletion(id='chatcmpl-A89uqVPOTAFjZQU7gDLK60Lwdf0fd', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The closest matching title to 'Mysticons' is 'Mysticons'.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508104, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=16, prompt_tokens=180, total_tokens=196, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# OpenAI API Response for Courage_the_Cowardly_Dog: ChatCompletion(id='chatcmpl-A89urHhi5wLphaLNmQAk87g0cIvtI', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The closest matching title to 'Courage_the_Cowardly_Dog' is 'Courage the Cowardly Dog'.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508105, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=25, prompt_tokens=185, total_tokens=210, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# OpenAI API Response for Tom_and_Jerry_Kids_Show: ChatCompletion(id='chatcmpl-A89uu8hWke3yVGEsaHfngPlzYAxi0', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The closest matching title is 'Tom and Jerry Kids Show'.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508108, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=12, prompt_tokens=184, total_tokens=196, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# OpenAI API Response for Bananas_in_pyjamas: ChatCompletion(id='chatcmpl-A89uvFkbrjHCgwIffJJmTEvIg1uUD', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The closest matching title is 'Bananas in Pyjamas'.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508109, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=13, prompt_tokens=183, total_tokens=196, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# OpenAI API Response for Bob_The_Builder: ChatCompletion(id='chatcmpl-A89uws5zGmIAFEc98c6k1MO9AueB5', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The closest matching title to 'Bob_The_Builder' is 'Bob the Builder'.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508110, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=18, prompt_tokens=182, total_tokens=200, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# OpenAI API Response for The_Land_Before_Time: ChatCompletion(id='chatcmpl-A89uzrDGOMs124rzNEJG45gblcrMa', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The closest matching title to 'The_Land_Before_Time' is 'The Land Before Time'.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508113, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=20, prompt_tokens=183, total_tokens=203, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# OpenAI API Response for Peppa's_Club: ChatCompletion(id='chatcmpl-A89v0ljX0XGPT9LlvK790QkOFFzhS', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="The closest matching title to 'Peppa's_Club' is 'Peppa's Club'.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1726508114, model='gpt-4-0613', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=21, prompt_tokens=183, total_tokens=204, completion_tokens_details=CompletionTokensDetails(reasoning_tokens=0)))
# Final DataFrame (After Merge with Excel):
#                                json_show  \
# 0                                 Molang
# 1                         Duck_And_Goose
# 2               Digimon_Digital_Monsters
# 3                      Tales_of_the_Jedi
# 4                Grizzy_and_the_Lemmings
# 5                          Polly_Pockets
# 6                            Pat_The_Dog
# 7                   Supernatural_Academy
# 8                              Mysticons
# 9   The_Doc_McStuffins_Christmas_Special
# 10              Courage_the_Cowardly_Dog
# 11               Tom_and_Jerry_Kids_Show
# 12                    Bananas_in_pyjamas
# 13                       Bob_The_Builder
# 14                  The_Land_Before_Time
#
#                            matched_title  \
# 0                                 molang
# 1                           duck & goose
# 2              digimon: digital monsters
# 3             avatar: the last airbender
# 4                grizzy and the lemmings
# 5                           polly pocket
# 6                            pat the dog
# 7                              mysticons
# 8                              mysticons
# 9   the doc mcstuffins christmas special
# 10              courage the cowardly dog
# 11               tom and jerry kids show
# 12                    bananas in pyjamas
# 13                       bob the builder
# 14                  the land before time
#
#                                    Title Age Rating  Age
# 0                                 molang     age 3+    3
# 1                           duck & goose     age 2+    2
# 2              digimon: digital monsters     age 6+    6
# 3             avatar: the last airbender     age 8+    8
# 4                grizzy and the lemmings     age 6+    6
# 5                           polly pocket     age 5+    5
# 6                            pat the dog     age 6+    6
# 7                              mysticons     age 7+    7
# 8                              mysticons     age 7+    7
# 9   the doc mcstuffins christmas special     age 4+    4
# 10              courage the cowardly dog    age 10+   10
# 11               tom and jerry kids show     age 5+    5
# 12                    bananas in pyjamas     age 3+    3
# 13                       bob the builder     age 3+    3
# 14                  the land before time     age 4+    4

# %%
final_df
# Out:
#                                json_show  \
# 0                                 Molang
# 1                         Duck_And_Goose
# 2               Digimon_Digital_Monsters
# 3                      Tales_of_the_Jedi
# 4                Grizzy_and_the_Lemmings
# 5                          Polly_Pockets
# 6                            Pat_The_Dog
# 7                   Supernatural_Academy
# 8                              Mysticons
# 9   The_Doc_McStuffins_Christmas_Special
# 10              Courage_the_Cowardly_Dog
# 11               Tom_and_Jerry_Kids_Show
# 12                    Bananas_in_pyjamas
# 13                       Bob_The_Builder
# 14                  The_Land_Before_Time
#
#                            matched_title  \
# 0                                 molang
# 1                           duck & goose
# 2              digimon: digital monsters
# 3             avatar: the last airbender
# 4                grizzy and the lemmings
# 5                           polly pocket
# 6                            pat the dog
# 7                              mysticons
# 8                              mysticons
# 9   the doc mcstuffins christmas special
# 10              courage the cowardly dog
# 11               tom and jerry kids show
# 12                    bananas in pyjamas
# 13                       bob the builder
# 14                  the land before time
#
#                                    Title Age Rating  Age
# 0                                 molang     age 3+    3
# 1                           duck & goose     age 2+    2
# 2              digimon: digital monsters     age 6+    6
# 3             avatar: the last airbender     age 8+    8
# 4                grizzy and the lemmings     age 6+    6
# 5                           polly pocket     age 5+    5
# 6                            pat the dog     age 6+    6
# 7                              mysticons     age 7+    7
# 8                              mysticons     age 7+    7
# 9   the doc mcstuffins christmas special     age 4+    4
# 10              courage the cowardly dog    age 10+   10
# 11               tom and jerry kids show     age 5+    5
# 12                    bananas in pyjamas     age 3+    3
# 13                       bob the builder     age 3+    3
# 14                  the land before time     age 4+    4
