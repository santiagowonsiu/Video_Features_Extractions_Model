# %%
# %pip install requests beautifulsoup4

# %%
### SCRAPE RATINGS

# %%
# Import the necessary libraries
import requests
from bs4 import BeautifulSoup

# URL of the page to scrape
url = "https://www.commonsensemedia.org/movie-reviews/bad-boys-ride-or-die"

# Fetch the content of the page
response = requests.get(url)
response.raise_for_status()  # Check if the request was successful

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Extract the movie title
title_element = soup.select_one("#content > div > div.one-column.row > div > div > div:nth-child(1) > div > div.row > div.col-8 > div > h1")
movie_title = title_element.get_text(strip=True) if title_element else 'No title found'

# Extract the rating age
rating_age_element = soup.select_one("#rating-a3770ea7-2bac-45f7-8736-b532ca04300a > span")
rating_age = rating_age_element.get_text(strip=True) if rating_age_element else 'No rating age found'

# Use the JavaScript path provided to find the specific content
review_content_div = soup.select_one("#review-view-content-grid > div.row")

# Find all child divs with the class 'content-grid-item content-grid-item--shadow'
child_divs = review_content_div.find_all('div', class_='content-grid-item content-grid-item--shadow')

# Extract the 'data-text' attribute, rating, and label from each child div
reviews = []
for idx, child_div in enumerate(child_divs, 1):
    data_text = child_div.get('data-text', 'No content found')
    data_text_cleaned = data_text.replace('<p>', '').replace('</p>', '')
    
    # Find the rating information within the same div
    rating_icons = child_div.select('span.rating__score i.active')
    rating = len(rating_icons) - 1  # Adjust rating by subtracting 1
    
    # Find the label within the same div
    label_span = child_div.select_one('span.rating__label')
    label = label_span.get_text(strip=True) if label_span else 'No label found'
    
    reviews.append({'data_text': data_text_cleaned, 'rating': rating, 'label': label})

# Print the movie title and rating age
print(f"Movie Title: {movie_title}")
print(f"Rating Age: {rating_age}\n")

# Print the extracted reviews
for idx, review in enumerate(reviews, 1):
    print(f"Review {idx}:")
    print(f"Label: {review['label']}")
    print(f"Content: {review['data_text']}")
    print(f"Rating: {review['rating']} out of 5\n")

# Optionally, save the extracted reviews to a file
with open('review_content.txt', 'w') as file:
    file.write(f"Movie Title: {movie_title}\n")
    file.write(f"Rating Age: {rating_age}\n\n")
    for idx, review in enumerate(reviews, 1):
        file.write(f"Review {idx}:\n")
        file.write(f"Label: {review['label']}\n")
        file.write(f"Content: {review['data_text']}\n")
        file.write(f"Rating: {review['rating']} out of 5\n\n")
# Out:
# Movie Title: Bad Boys: Ride or Die
# Rating Age: age 16+
#
# Review 1:
# Label: Positive Messages
# Content: Like the other films in the series, the theme of family (and bonds of friendship) is present underneath the over-the-top action. Characters are encouraged to form better relationships with loved ones, and the main characters both have a strong sense of duty and devotion to their superiors -- even though they blow everything up and face no consequences, they're trying to do the right thing. Anxiety is treated lightly/dismissively.
#
# Rating: 2 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: The main characters are likable, but they're also unapologetically violent and crude and never face any consequences. Even their family-like bond now seems stretched thin. One character struggles with the misconception that he's "cursed" and brings violence down upon his loved ones; he begins to suffer panic attacks, which isn't taken/discussed seriously and is solved with a simple slap on the face and someone saying saying "it's not your fault." Another character has a near-death experience and realizes that he has "nothing to fear," which dissolves into a series of jokes about how he tests this theory.
#
# Rating: 1 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: The two lead characters and many others are Black; co-directors Adil El Arbi and Bilall Fallah are Belgian filmmakers of Moroccon descent. Black performers/athletes Tiffany Haddish, John Salley, and DJ Khaled appear in small roles. Police captain Rita Secada is played by Paola Núñez, who was born in Mexico. Jacob Scipio, who plays Mike's son, Armando, has Indo-Guyanese and English ancestry. Vanessa Hudgens, who co-stars as Kelly, is of Filipina descent. These are all heroic roles; most of the villainous roles are played by White men. In one scene, Mike and Marcus are forced to steal clothes from two White Miami residents, and there's some dialogue suggesting that they may be White supremacists, but this isn't condoned in any way. A White man in a prison scene has a Swastika tattoo. Key female characters are tough, but they're also largely bystanders/supporters of the male characters; some women are objectified. A form of torture in which fingernails are removed is referred to as a "Colombian manicure."
#
# Rating: 3 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: Guns used to threaten and shoot, with blood spurts and deaths. Women are kidnapped and held at gunpoint. A man beats a woman up in an elevator car, slamming her face against the wall, etc. During a prison yard fight, a character uses a barbell weight to bash opponents in the head. Knife threat, knife fights, stabbing and slicing. Car chases and crashes. Plane crashes into building, with a character shredded by the propellor. Vehicle slams into character. Vehicle on fire. Helicopter crash. Explosions. Bombs dropped via drone. Grenade. Fighting, punching, kicking, slapping. Character collapses from a heart attack. A man shoots a woman in the face, off-camera, to make it look like she died by suicide. Description of "Colombian manicure," in which a character's fingernails are forcibly removed with pliers; brief flash of character screaming in pain. Characters are bitten/eaten by a giant alligator. Character stands on ledge of tall building. Character walks into busy street, nearly hit by traffic. Character has nightmare that includes violent flashbacks from previous movies. Panic attacks. Swastika tattoo. A man tries to coerce his wife into bed but is interrupted.
#
# Rating: 4 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: A man lifts his hospital gown, with his back to the camera, supposedly exposing his private parts; a gust of wind lifts his gown, and his buttocks are briefly exposed. Strong sex-related dialogue and sexual gestures. Women pole-dance in a strip club (no nudity). Two co-workers are caught having a secret relationship. Shirtless male. Gratuitous montage of women in bikinis. Kissing. A man gestures for a woman to sit on his lap.
#
# Rating: 3 out of 5
#
# Review 6:
# Label: Language
# Content: Near-constant, extremely strong language includes "f--k," "s--t," "motherf----r," "t-ts," "bulls--t," "p---y," "son of a bitch," "ass," "dumbass," "d--k," "bastard," "damn."
#
# Rating: 5 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content: Bags of Doritos chips and packages of Skittles candy are prominently displayed/mentioned. Character wears a Bud Light T-shirt. Ding Dongs and Coke are mentioned.
#
# Rating: 3 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: Character drinks a glass of whiskey mixed with Pepto Bismol. Mentions of drugs (cocaine, ecstasy, etc.).
#
# Rating: 2 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5

# %%
# SCRAPE LINKS

# %%
import requests
from bs4 import BeautifulSoup

def extract_links(url, filter_prefixes):
    response = requests.get(url)
    response.raise_for_status()  # Check if the request was successful
    soup = BeautifulSoup(response.content, 'html.parser')
    links = soup.find_all('a', class_='link--title')
    filtered_links = [{'title': link.get_text(strip=True), 'url': link['href']} for link in links if any(link['href'].startswith(prefix) for prefix in filter_prefixes)]
    return filtered_links

# URLs of the pages to scrape
movie_url = "https://www.commonsensemedia.org/search/animated%20tv%20shows"
# tv_url = "https://www.commonsensemedia.org/lists/offbeat-animated-movies"

# Filter prefixes
filter_prefixes = ['/movie-reviews', '/tv-reviews']

# Extract links from both URLs
movie_links = extract_links(movie_url, filter_prefixes)
tv_links = extract_links(tv_url, filter_prefixes)

# Combine the lists
all_links = movie_links + tv_links

# Print the list of titles and URLs
print("List of movie and TV review links:")
for link in all_links:
    print(f"Title: {link['title']}, URL: {link['url']}")

# Optionally, save the list of links to a file
with open('review_links.txt', 'w') as file:
    for link in all_links:
        file.write(f"Title: {link['title']}, URL: {link['url']}\n")
# Out:
# List of movie and TV review links:
# Title: I Saw the TV Glow, URL: /movie-reviews/i-saw-the-tv-glow
# Title: Quiet on Set: The Dark Side of Kids TV, URL: /tv-reviews/quiet-on-set-the-dark-side-of-kids-tv
# Title: Zombies: The Re-Animated Series, URL: /tv-reviews/zombies-the-re-animated-series
# Title: Ark: The Animated Series, URL: /tv-reviews/ark-the-animated-series
# Title: The 8 Show, URL: /tv-reviews/the-8-show
# Title: The Magic Prank Show with Justin Willman, URL: /tv-reviews/the-magic-prank-show-with-justin-willman
# Title: Jerrod Carmichael Reality Show, URL: /tv-reviews/jerrod-carmichael-reality-show
# Title: The Vince Staples Show, URL: /tv-reviews/the-vince-staples-show
# Title: The Addams Family (Animated TV Series), URL: /tv-reviews/the-addams-family-animated-tv-series
# Title: Catfish: The TV Show, URL: /tv-reviews/catfish-the-tv-show
# Title: Spider-Man (1981 TV Show), URL: /tv-reviews/spider-man-1981-tv-show
# Title: Ape Star, URL: /movie-reviews/ape-star
# Title: Ernest & Celestine, URL: /movie-reviews/ernest-celestine
# Title: Ernest and Celestine: A Trip to Gibberitia, URL: /movie-reviews/ernest-and-celestine-a-trip-to-gibberitia
# Title: Moomins and the Winter Wonderland, URL: /movie-reviews/moomins-and-the-winter-wonderland
# Title: Yellow Submarine, URL: /movie-reviews/yellow-submarine
# Title: Chicken Run, URL: /movie-reviews/chicken-run
# Title: Fantastic Mr. Fox, URL: /movie-reviews/fantastic-mr-fox
# Title: Felix and the Hidden Treasure, URL: /movie-reviews/felix-and-the-hidden-treasure
# Title: The Garfield Movie, URL: /movie-reviews/the-garfield-movie
# Title: James and the Giant Peach, URL: /movie-reviews/james-and-the-giant-peach
# Title: The Nightmare Before Christmas, URL: /movie-reviews/the-nightmare-before-christmas
# Title: Song of the Sea, URL: /movie-reviews/song-of-the-sea
# Title: Strike, URL: /movie-reviews/strike
# Title: Wallace & Gromit, URL: /movie-reviews/wallace-gromit
# Title: 10 Lives, URL: /movie-reviews/10-lives
# Title: Arlo the Alligator Boy, URL: /movie-reviews/arlo-the-alligator-boy
# Title: Howl's Moving Castle, URL: /movie-reviews/howls-moving-castle
# Title: Leo, URL: /movie-reviews/leo
# Title: Marcel the Shell with Shoes On, URL: /movie-reviews/marcel-the-shell-with-shoes-on
# Title: A Monster in Paris, URL: /movie-reviews/a-monster-in-paris

# %%
## SCRAPE RATINGS FOR A WHOLE TXT LIST

# %%
# Import the necessary libraries
import requests
from bs4 import BeautifulSoup

# Base URL of the website
base_url = "https://www.commonsensemedia.org"

# Function to scrape and process each URL
def scrape_and_process_url(title, url):
    # Full URL
    full_url = base_url + url

    # Fetch the content of the page
    response = requests.get(full_url)
    response.raise_for_status()  # Check if the request was successful

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extract the movie title
    movie_title = title

    # Extract the rating age
    rating_age_element = soup.select_one("#rating-a3770ea7-2bac-45f7-8736-b532ca04300a > span")
    rating_age = rating_age_element.get_text(strip=True) if rating_age_element else 'No rating age found'

    # Use the JavaScript path provided to find the specific content
    review_content_div = soup.select_one("#review-view-content-grid > div.row")

    # Find all child divs with the class 'content-grid-item content-grid-item--shadow'
    child_divs = review_content_div.find_all('div', class_='content-grid-item content-grid-item--shadow')

    # Extract the 'data-text' attribute, rating, and label from each child div
    reviews = []
    for idx, child_div in enumerate(child_divs, 1):
        data_text = child_div.get('data-text', 'No content found')
        data_text_cleaned = data_text.replace('<p>', '').replace('</p>', '')

        # Find the rating information within the same div
        rating_icons = child_div.select('span.rating__score i.active')
        rating = len(rating_icons) - 1  # Adjust rating by subtracting 1

        # Find the label within the same div
        label_span = child_div.select_one('span.rating__label')
        label = label_span.get_text(strip=True) if label_span else 'No label found'

        reviews.append({'data_text': data_text_cleaned, 'rating': rating, 'label': label})

    return {
        'movie_title': movie_title,
        'rating_age': rating_age,
        'reviews': reviews
    }

# Read URLs from review_links.txt
with open('review_links.txt', 'r') as file:
    lines = file.readlines()

# Process each URL and store results
all_reviews = []

for line in lines:
    line = line.strip()  # Remove any leading/trailing whitespace
    if line:
        title_part, url_part = line.split(', URL: ')
        title = title_part.replace('Title: ', '').strip()
        url = url_part.strip()
        review_data = scrape_and_process_url(title, url)
        all_reviews.append(review_data)

# Print the results
for review_data in all_reviews:
    print(f"Title: {review_data['movie_title']}")
    print(f"Rating Age: {review_data['rating_age']}\n")
    
    for idx, review in enumerate(review_data['reviews'], 1):
        print(f"Review {idx}:")
        print(f"Label: {review['label']}")
        print(f"Content: {review['data_text']}")
        print(f"Rating: {review['rating']} out of 5\n")
    print("\n")

# Optionally, save all reviews to a file
with open('all_reviews_content.txt', 'w') as file:
    for review_data in all_reviews:
        file.write(f"Title: {review_data['movie_title']}\n")
        file.write(f"Rating Age: {review_data['rating_age']}\n\n")
        for idx, review in enumerate(review_data['reviews'], 1):
            file.write(f"Review {idx}:\n")
            file.write(f"Label: {review['label']}\n")
            file.write(f"Content: {review['data_text']}\n")
            file.write(f"Rating: {review['rating']} out of 5\n\n")
# Out:
# Title: Power of the Dream
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: Women deserve equal rights and equal pay. Black lives matter as much as any other lives. Individual acts can have collective impact.
#
# Rating: 4 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Professional women basketball players stand up for what they believe in, despite a risk to their own livelihoods. They talk about a sisterhood and the importance of using their platform to advocate for social justice issues of importance to their communities, particularly "Black and Brown women."
#
# Rating: 4 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: The WNBA started in the 1990s and is comprised predominantly of Black women. Many of the players are gay, leading women interviewed to say they see parallels between struggles around sexuality, gender, race, and class. They decide to use their platform for good and dedicate their season to social justice, engaging in activism on behalf of "Black lives." Professional female athletes earn significantly less than their male counterparts. They negotiate a new contractual agreement with an 83% pay raise and paid maternity leave.
#
# Rating: 4 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: Footage shows some of the Black people killed by police in recent years, as well as related protests and riots. There is discussion of "state-sanctioned violence" against Black people, White supremacy, death threats and self-censorship, and the disproportional negative impact of the pandemic on women of color.
#
# Rating: 2 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content:
# Rating: -1 out of 5
#
# Review 6:
# Label: Language
# Content: "F--k," "s--t," "bulls--t," "sissies."
#
# Rating: 3 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content: WNBA and NBA teams, sports brands, sponsors, and gear, media outlets, social media platforms, cars, clothes, political organizations, political parties, and more.
#
# Rating: 3 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: Players celebrate with flutes of champagne.
#
# Rating: 1 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Bad Behaviour
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: Enlightenment can't be taught or bought. Communication and understanding can lead to closer connection. Trauma can be passed down through generations.
#
# Rating: 2 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Lucy wants to work on herself, but concentrates on podcasts and retreats by a questionable guru that don't seem to help. She struggles with depression and past trauma, which make her closed off and cynical toward others, including her daughter, Dylan. Dylan is adventurous and behaves erratically at times, putting herself in physical danger and being attracted to men who behave badly. Both struggle to communicate with each other after years of disconnect.
#
# Rating: 1 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: Women in main roles, and writer/director is female. Characters are mostly White, with some actors of Māori and Samoan decent in supporting roles. References to self-harm (cutting), depression, alcoholism, eating disorders, and suicide. The word "nuts" is used for someone struggling with mental health issues.
#
# Rating: 2 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: A violent outburst sees a person throw water on someone's face before hitting them over the head with a chair. They're seen passed out with an injury to the head and later carried off on a stretcher. References to self-harm (cutting), eating disorders, and suicide. A suicide attempt is mentioned, involving a character taking sleeping pills, drinking alcohol, and jumping off a roof. Movie stunts include strangling, pretending to be shot, and other dangerous moves, and a character is seen with bruises on their back while undressing. A person is accidentally hit in the face and falls down an incline, resulting in a head injury and concussion -- bloody head wounds shown. A character mentions their father being a bully and wanting to kill him. A scary dream includes a threatening voice and strange visions, and an animated dream segment shows a plane plunging toward the ground, but the crash doesn't happen. Video games are seen that include shooting zombies with rifles.
#
# Rating: 3 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: Kissing on the lips and neck, and undressing, and the implication that sex has taken place. Mention of condoms.
#
# Rating: 2 out of 5
#
# Review 6:
# Label: Language
# Content: Language includes "c--t," "f--k," "f---ing," "s--t," "a--hole," and exclamations of "Jesus Christ," and "oh my God." Middle finger gesture.
#
# Rating: 4 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content: Numerous Tesla cars seen in a parking lot.
#
# Rating: 1 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: Characters smoke cigarettes and drink alcohol. One binges on alcohol miniatures to get drunk and is seen to be intoxicated in a hallway. Reference to alcoholism.
#
# Rating: 3 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Ultraman: Rising
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: The film shows how members of various generations of a family will do anything to support each other. Men can be caretakers, just like women. Revenge doesn't feel good. Individuals should seek balance in life.
#
# Rating: 4 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Ken learns humility, teamwork, and gratitude in being forced to care for another creature and put its needs above his own. He also realizes the care his parents showed in raising him, and he turns to his father for help raising the creature. The father helps selflessly. Another character wants revenge for the loss of his family. AI assistants are portrayed as caring and helpful.
#
# Rating: 4 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: The main character is Japanese American. He says he was bullied as a child for being different. The film shows some local customs, sights, and cultural products of Tokyo. A man grows to love a baby from another species formerly believed to be adversaries. Men discuss their love for their families and assume caretaking roles for children.
#
# Rating: 3 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: A giant superhero and government defense forces battle equally giant monsters known as kaiju, who appear intent on destroying Tokyo. Their skirmishes involve falls, crashes, weapons, fire, danger, broken bones, and destruction. Characters, including a baby and an elderly man, are put in harm's way and presumed dead in different scenes. At least one character is killed. A mother and wife has gone missing; her son was bullied as a child for being different. A baby vomits, poops, and has acid reflux. A beloved AI figure dies.
#
# Rating: 3 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content:
# Rating: -1 out of 5
#
# Review 6:
# Label: Language
# Content: "Hell," "crap," "bull," "suck," "heck," "fart," "poopy."
#
# Rating: 2 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content: The film could introduce unfamiliar audiences to an existing franchise. Dodgers, Giants, Tokyo.
#
# Rating: 1 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: Ken drinks multiple cans of what might (or might not) be beer in one scene.
#
# Rating: 1 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Reverse the Curse
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: Demonstrates how honest communication, rather than keeping secrets, creates stronger and more loving relationships.
#
# Rating: 3 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Characters are likable but not very admirable overall. They do iffy things, even if sometimes with the best intentions. Mostly they're just struggling and trying to find connection.
#
# Rating: 2 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: The two main characters are White men. Stephanie Beatriz, who was born in Argentina to a Colombian father and a Bolivian mother, plays Death Specialist Mariana, who's a little underwritten (she doesn't really do much in her job, and she's mostly there as a crush for Ted) but is still important to the story. At one point, a character refers to Mariana as a "spic." Another character protests, saying it's offensive, but she defends it as a term of endearment. In a touching scene, Marty visits a lost love, Eva, played by Daphne Rubin-Vega, who's of Panamanian heritage. A character jokingly does yoga "Jewish style," grunting "oy vey" as he stretches.
#
# Rating: 2 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: Character with cancer coughs up blood; bloody tissues are seen around the house. Dialogue about being shot ("if you get shot, you don't have to die"). Disturbing flashbacks to infant with double pneumonia. Dialogue about a dead child. Brief references to death via suicide.
#
# Rating: 2 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: A couple kisses passionately and wakes up next to each other (sex implied). Tender kissing. Men's naked bottoms seen in locker room. Two men examine each other's private parts, which are off-camera. A couple pretends to have sex behind a closed door; it's revealed that they're only making sex noises and bouncing on the bed. Strong sex-related dialogue.
#
# Rating: 3 out of 5
#
# Review 6:
# Label: Language
# Content: Fairly frequent language, with uses of "f--k," "s--t," "motherf-----r," "t-ts," "a--hole," "goddamn," "ass," "culo," "bastard," "piss," "Jesus Christ," "hell," "prick," "vagina," "blow me/blow you," "moron," "masturbating." Scatological jokes. A young boy sends out a comical stream of amateur curses ("ass nipple," "boo penis," "eat my balls," "big boob whore"), including several uses of "f--k."
#
# Rating: 4 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content: A character is said to have worked in advertising, coming up with famous slogans like "a little dab'll do ya" (for Brylcreem) and "double your pleasure." (Doublemint gum is also mentioned.) Character craves Twinkies.
#
# Rating: 1 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: Main character smokes pot throughout and shares it with his father, "shotgunning" smoke into his mouth. Joint-rolling. Caracter expounds upon the virtues of pot. Casual beer-drinking. Cigarette smoking. A character may have cancer due to smoking cigarettes. Character mentions "OD-ing on Seconal and quaaludes." Character threatens to take a handful of prescription pills. Character refers to pot as a "gate" (i.e. gateway) drug. Cocaine mentioned. Character reads a book called <em>On Hashish</em>.
#
# Rating: 4 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Federer: Twelve Final Days
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: Athletes must retire, and they know their time playing professionally is limited. Retirement doesn't have to be an "end," but can be the beginning of something new.
#
# Rating: 3 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Federer expresses gratitude and many emotions at the end of his long and successful professional tennis career, as do his wife, parents, coaching team, and fans. He was known for his elegant playing style, and he was beloved by fans. Federer and his family appear to have very loving relationships. Pro players maintain friendships with other professionals, but they also are seen gossiping in one locker room scene.
#
# Rating: 4 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: The top professional players in tennis come from all over the world, including Federer (Switzerland) and others in this film, such as Raphael Nadal (Spain), Novak Djokovic (Serbia), Bjorn Borg (Sweden), and Andy Murray (Scotland). Federer can be heard speaking in French and German at times, but he speaks mostly English with his extensive team.
#
# Rating: 2 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: Federer describes undergoing multiple injuries and surgeries, which ultimately derail his career.
#
# Rating: 1 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: Federer and his wife hug and kiss.
#
# Rating: 1 out of 5
#
# Review 6:
# Label: Language
# Content: "F--k" is heard in passing a couple of times.
#
# Rating: 3 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content: Federer's brand as well as other sporting brands, clothing, leagues, tournaments, awards, sponsors, and so on. Pro tennis players earn a lot of money and travel in luxury. Athletes are brand ambassadors.
#
# Rating: 2 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content:
# Rating: -1 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Brats
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: Young people deserve to be taken seriously. Youth is a time to experiment and even make mistakes. Journalists must consider their power to impact lives with their words. It can be healthy to revisit the past and try to come to terms with events and experiences.
#
# Rating: 3 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Actor and director Andrew McCarthy confronts his complicated feelings about the past by reaching out to old friends and colleagues and engaging in truthful discussion about their experiences and emotions. The old friends are (mostly) there for him, despite not having been in touch for decades. McCarthy confronts a journalist who wrote an unflattering article years earlier, and the two have an honest conversation about their differing perspectives.
#
# Rating: 3 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: The so-called "Brat Pack" was a group of all-White actors in the 1980s. A Black interviewee comments on the historical lack of non-White characters in Hollywood films and series, and he suggests non-White audiences have learned to feel comfortable understanding and identifying with White characters.
#
# Rating: 1 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: People mention trauma they've had or worked through with therapy.
#
# Rating: 1 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: Characters in older films are shown in bed together and kissing. Archive footage also scrolls past a "peep show" sign in New York City.
#
# Rating: 2 out of 5
#
# Review 6:
# Label: Language
# Content: Use of "f--k," "brat," "fool."
#
# Rating: 3 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content: This film was inspired by a book written by the director and includes mention of and footage from a series of 1980s-era movies. Also seen are a variety of media outlets, movie theater chains, Los Angeles and New York settings, and cars.
#
# Rating: 2 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: In old interviews and movie clips, people drink and smoke. There's mention of an actress needing a "sober partner" on set. A person also talks about getting high and drunk in the past.
#
# Rating: 3 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Mysteries of the Terracotta Warriors
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: Work as a team to figure out mysteries and uncover new pieces of history. Positive messages of perseverance, curiosity, and teamwork.
#
# Rating: 3 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Various scientists, historians, and archeologists work tirelessly to excavate various archeological sites, examine specimens, and provide insight into what actually happened to the first emperor, Qin Shi Huangdi.
#
# Rating: 3 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: The primary cast are Chinese scientists, historians, scholars, and archeologists. Women and men are featured who are experts in relevant fields. Sexuality is not represented except for noting that former emperors had women "concubines." Historians mention the "concubines" were young women who were encouraged to be skinny.
#
# Rating: 2 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: All violence is from either narrated historical records or dramatizations of history. Some of these show killing, brief blood, and battle violence. In battle, soldiers kill, stab, and impale others with spears, arrows, and sword slashes. A man kills himself by slashing his own neck with a small sword. Blood splatter sounds but not shown. A man cuts the throat of another man. Another character forces a man to drink poison, killing him. Archeologists excavate some tombs that have many mutilated bodies. Most of the bodies have also been dismembered.
#
# Rating: 4 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: A dramatization of an emperor's "concubines" talks about how they were murdered after the emperor fell.
#
# Rating: 1 out of 5
#
# Review 6:
# Label: Language
# Content:
# Rating: -1 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content:
# Rating: -1 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content:
# Rating: -1 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: The Old Oak
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: Community and solidarity are important, and empathy and teamwork are great character strengths. Love and loss are universal experiences. Don't take your own problems out on others. It takes strength and faith to hope, but hope can be both inspiring and cause pain. Hate, lies, corruption, and betrayal are strong forces. Hard work doesn't always pay off.
#
# Rating: 3 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: TJ is kind and empathetic toward others. He tries to calm local people expressing racist views and helps refugees settle into their homes. He's generous with what little he has, trading his uncle's old cameras to help Yara fix hers, and is warm and loving toward his dog. Yara is confident and hardworking. She's not afraid to stand up for herself and others, and challenges herself, such as learning 20 English words a day while helping nurses in a refugee camp. She also shows kindness to a local teen who falls ill and toward TJ when he struggles. She's a talented photographer and immerses herself in the local community through photography. Both TJ and Yara show empathy and teamwork, and many members from the community learn from their examples -- though some remain stuck in their racist, embittered views.
#
# Rating: 3 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: Both White British and Syrian characters are given complexity, and are shown to be united by their similarities. Syrian characters are played by Syrian people. Though the film is written and directed by White Men, real-life refugee stories were gathered by the writer and director prior to the film, and Amna Al Ali, who plays the mother of central character Yara, arrived in the U.K. as a refugee from Syria in 2008. Some local people express strongly racist views and use racist language toward the Syrian refugees, and only sometimes do other characters call them out. A supporting character uses a wheelchair, but is wheeled in and out of scenes without being given a role beyond. Set in an old mining town in the north of England, most English characters are seen to be financially struggling and show little hope of future prospects.
#
# Rating: 3 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: White characters intimidate Syrian characters, verbally harassing them with racist language, and one steals a camera from another, which ends up getting broken. A person shoves another out of their house and they stumble on to the pavement. Bullying at school involves hitting and kicking on the ground, resulting in blood on the face -- and filming the attack on a smartphone. Pitbull dogs behave aggressively and attack a smaller dog, which is killed by them off-screen. There are suicide references when a character talks about a past intention to take their own life. Mention of bombs, refugee camps, overcrowded prisons, beatings and torture, chlorine gas, militia, and news footage shows children being pulled from the rubble of a bombed school. Mention of the death of parents.
#
# Rating: 3 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: Passing sexual reference, where a customer suggests the barman is "slipping her a length" when talking about Yara. Mention of "shagging," British slang for sex.
#
# Rating: 2 out of 5
#
# Review 6:
# Label: Language
# Content: Frequent strong language includes "c--t," "f---ing," "f----r," "f--k," "s--t," "s--ting," "s--thole," "shite," "hell," "piss," "d--k," "bastards," "a--hole," "crap," "bloody," and the British swear word "wanker." There's name-calling such as "nutter," "moron," "loser," "parasites," "scab," and "pedos," plus exclamations of "Jesus Christ." Racist language includes "Paki," "dirty immigrant" "foreign bastard," "f---ing ragheads," "crazy f---ing Jihadi," and "Ali Baba and the Forty Thieves."
#
# Rating: 4 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content: Guinness mentioned and logos for Waterstones bookshop and kitchen condiments including Heinz, HP, and Sarson's vinegar shown.
#
# Rating: 2 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: Characters drink pints of beer in a pub on numerous occasions. A character vapes.
#
# Rating: 3 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Origin
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: Argues that it's our responsibility as humans to learn from our past to improve the present. Explores triumphs and challenges of outcasts and "untouchables" in three historical contexts: Black Americans experiencing institutional racism during slavery and in Jim Crow South, European Jews targeted for subjugation and extermination in Nazi Germany, and the Dalit population being dehumanized in India. Shows how activists and anyone fighting a dominant culture's rules can put their lives at risk in the face of cruelty and terror. Major themes include courage, integrity, self-control, perseverance. Isabel Wilkerson's personal story sheds light on how people can work through grief and loss.
#
# Rating: 5 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Isabel is smart, curious, empathetic, thoughtful, kind. She's a dedicated researcher and a devoted daughter, wife, and friend. Brett and Marion are loving, attentive, and supportive to Isabel. August Landmesser stood up to the Nazi regime in small but impactful ways. Dr. B.R. Ambedkar is a prominent human rights activist who fought for justice and equality for the Dalit people.
#
# Rating: 4 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: Made by predominantly Black filmmakers (including writer-director Ava DuVernay) and has a largely Black cast and crew. Based on nonfiction book by and personal story of Pulitzer Prize-winning Black journalist/author Isabel Wilkerson, centering on her story and experiences. Includes little-known stories about Black researchers in the 1930s and the Dalit activist (and double Ph.D.) who fought for human rights in India. Also depicts heartbreaking stories about caste- and race-based dehumanization of Black people, the Jewish community in Nazi Germany, and the Dalit people in India.
#
# Rating: 5 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: Many disturbing, upsetting scenes. Main character faces tragic personal loss; people suffering from illness are shown near death and dead (not graphic). Reenactments of race-based, faith-based, and caste-based discrimination and violence. A lynching is depicted as a fun afternoon picnic for White attendees, even after the victim's legs are visible swinging from a tree (whole body not shown). A Jewish mother is shot for trying to run to her child during a forced separation at a concentration camp; other mothers scream in terror. A married couple yell and push against captors as their young, crying daughters are found in the back of their truck. Shackled Black Africans weep and cry out during the Middle Passage. Rape is implied when a White man pulls an African woman's legs toward him, and she starts to cry even harder. Dehumanization/cruelty montages portray how Dalit men are forced to work in excrement as they unclog public bathroom facilities. Reenactment of Trayvon Martin's murder. Interviewees share sad/upsetting personal experiences.
#
# Rating: 3 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: Isabel and Brett kiss a few times, as do August and Irma in flashbacks to 1930s-'40s Germany. They also swing dance, and she sits on his lap. Two other married couples hold hands and hug. Nonsexual nudity (shoulders, legs, backs) of enslaved people on a ship.
#
# Rating: 2 out of 5
#
# Review 6:
# Label: Language
# Content: Racial slurs like the "N" word (once), "monkey," "boy," "gal," "you," and charged language like "uppity," "too big for his britches," "those people," "looks like a criminal," etc. Infrequent use of "s--t."
#
# Rating: 3 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content:
# Rating: -1 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: Adults are briefly shown with cigarettes and drinking alcohol at a dance club. Social drinking.
#
# Rating: 2 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Hit Man
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: A person's identity or personality doesn't have to be set in stone; humans can change, evolve, and reinvent themselves. Love can curdle into hate, and people are capable of doing very bad things in the name of both of those emotions.
#
# Rating: 2 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Gary is a nerdy professor who uses his many talents to freelance for the police, helping catch people attempting to hire a hit man to kill others. He also gets wrapped up in one of his more attractive invented personas and begins crossing ethical lines. Another police character also acts unethically. Madison attempts to reconstruct her life after an abusive relationship, but she gets drawn back into the violence. She's also reinventing herself and, at times, playing a character. Characters commit violent acts.
#
# Rating: 2 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: The female lead, Puerto Rican actress Adria Arjona, could be considered a stereotype of the intense, sexy Latina; her character isn't given many interests or much purpose outside of the men in her life. The main character, who's White, is based on a real person. The students in his university classes are diverse. His female colleague and male superior on the police team are Black. An unethical policeman, who is White, is on leave for beating up some teenagers, causing a PR problem for the local force. Another police colleague is played by an Indian American actor, and one scene suggests he's gay or bisexual. Among the characters who try to hire an assassin, several could be considered stereotypes of lower-income White Southerners, including one gun rights advocate.
#
# Rating: 2 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: Significant discussion and description of bodily harm, but little is shown beyond one death by poison and strangulation. One character pulls a gun on another. Archive footage of scenes of violence from old movies and TV shows. The main character, as a fake assassin, invents descriptions of how he kills, dismembers, and disposes of people's bodies. He also describes specific methods individuals might use to die via suicide. People hiring him talk about wanting to get rid of someone in their lives, including a teenage boy who pays to have his mother killed. Reference to the Second Amendment, school shooters, police beatings, dirty cops, and cancel culture.
#
# Rating: 4 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: Two adults kiss and have sex in a variety of positions and in various scenes. No intimate body parts are seen, though they're hinted at, and a man is shown shirtless and a woman in her bra. They take a bath together. In a scene at a strip club, women are seen in lingerie. There's mention of a man being "hung like a straw" versus a "nightstick."
#
# Rating: 3 out of 5
#
# Review 6:
# Label: Language
# Content: "F--k," "s--t," "a--hole," "damn," "goddamn," "hell," "d--k," "bitch," "son of a bitch," "douche," "sucks," "p---y," "slut," "balls," "geez," "weird."
#
# Rating: 4 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content: Car brands, University of New Orleans, New Orleans Police Department. A running joke revolves around a man's status being defined by the fact that he drives a Honda Civic.
#
# Rating: 1 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: Adults drink alcohol and smoke cigarettes. A police officer drinks from a flask while on duty. A person is drugged into unconsciousness. A person is killed after what police believe is a drug deal gone wrong.
#
# Rating: 2 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Hard Miles
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: Hard work overcomes hard luck. If you set a goal, no matter how impossible, you can achieve it through hard work and determination. You decide who you can and can't be, you decide what you can and can't do. Strong themes of the benefits of perseverance, teamwork, resilience, and forgiveness.
#
# Rating: 5 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Greg Townsend is a social worker in a Colorado correctional high school who creates a cycling team of incarcerated teens. He demonstrates the rewards of hard work, teamwork, and perseverance, and encourages interest in and curiosity about the wider world. Co-worker Haddie is a child psychologist who serves as a voice of reason and brings balance to Greg's stubborn, sometimes harsh methods, supporting the teens and the team. The boys' stories include a range of individual struggles; they grow both as individuals and a team.
#
# Rating: 4 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: Main character Greg Townsend (Matthew Modine) is a White man; other school staff members include principal/head adminstrator Skip, who's Black, and counselor Haddie, an Afro-Latino woman. Haddie is the only female character with more than five lines; she says what she thinks, but she's also fulfilling a stereotype in her role as a nurturing, caring Black woman (she literally drives what's referred to as the "support wagon"). Incarcerated teens have White and Brown skin and are played by actors who identify as AAPI and Latino. Smink, a student, has an eating disorder, but it doesn't define him. He's played by Jackson Kelly, who's open with his own struggles with this diagnosis. It's rare to see a male character in mainstream media with anorexia or bulimia, and conversations between the counselors revolve around how to interact with someone with this diagnosis without creating a bigger issue. Boys talk about girls in a generally derogatory way, as in "get me some bitches."
#
# Rating: 3 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: Teens brawl in school, injuring a teacher. Flashbacks to show why the boys are incarcerated, some including a gun. Domestic abuse indicated through a memory in which a child is smacked across the face. Verbal references to stabbing and murder. Suicidal ideation. Yelling. Vomiting.
#
# Rating: 3 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: "That's what she said" and a few other suggestive jokes.
#
# Rating: 1 out of 5
#
# Review 6:
# Label: Language
# Content: Strong language throughout, especially from the teens, who are quick to insult each other. Words include "ass," "balls," "bulls--t," "a--hole," "bitch," "damn," "s--t," "f--k," "son of a bitch," "oh my God," and "what the hell." There's some admonishment for using profanity. Boys talk about girls in a generally derogatory way, as in "get me some bitches." Humorous conversation about the pain in the groin that comes with long-distance cycling includes terms referring to the area, like "squee," "gooch," "grundle," and "taint." Greg insults students a couple of times ("stupid crybabies") and then realizes the negative impact of his words.
#
# Rating: 4 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content: A couple of references to products that aren't seen, including Butt Butter and Slim Jims.
#
# Rating: 1 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: Underage drinking. Flash of bottles of alcohol shown to suggest why one of the teens is in the juvenile correctional facility. Drawing of a cigarette. Jokes about smoking marijuana.
#
# Rating: 3 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Am I OK?
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: Friendship is important and can change over time as you do. It's important to explore who you are and find yourself -- regardless of age. Have the courage to pursue your dreams. Life doesn't always go to plan, and new beginnings can be scary, but also exciting and rewarding.
#
# Rating: 3 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Lucy is initially stuck in her life, doing the same things and not making any changes or opening herself up to new experiences. Jane is more confident and impulsive, and tries to bring Lucy out of her shell, but sometimes makes assumptions about what Lucy needs. Both value their friendship and are supportive toward each other, though can also be hurtful when things get difficult.
#
# Rating: 3 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: The movie centers a woman exploring her sexuality and coming out as a lesbian in her 30s, whereas coming-out movies more often focus on teens. As well as LGBTQ+ representation on-screen, directors <a href="/search/Tig%20Notaro">Tig Notaro</a> and Stephanie Allynne are lesbians, and the movie is inspired by the experiences of writer Lauren Pomerantz, who herself came out in her 30s. Stereotypes are used, but poked fun at, such as a straight character saying "I've always wanted to try it" regarding lesbian sex, and a boyfriend appearing impressed and sexualizing the fact that his girlfriend kissed a girl at school. While lead actor <a href="/search/Dakota%20Johnson">Dakota Johnson</a> is White, her best friend is played by <a href="/search/Sonoya%20Mizuno">Sonoya Mizuno</a>, who has Japanese, Argentine, and English heritage, and Black actor <a href="/search/Jermaine%20Fowler">Jermaine Fowler</a> and biracial (Black and White) actor <a href="/search/Kiersey%20Clemons">Kiersey Clemons</a> play supporting roles.
#
# Rating: 3 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content:
# Rating: -1 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: Kissing and undressing. Implication sex has taken place when two people wake up in bed together -- underwear is seen, and sheets held up to cover breasts. Frequent sexual references -- including oral and anal sex, erections, and masturbation. A person is seen on the toilet (no nudity).
#
# Rating: 3 out of 5
#
# Review 6:
# Label: Language
# Content: Language includes "f--k," "f---ing," "s--tty," "s--tfaced," "bitch," "bastard," "ass," "crap," and exclamations of "oh my God," "Jesus," and "Christ." Middle finger gesture.
#
# Rating: 4 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content: References to brands including Cadbury, 7-Eleven, Volvo, Uber, Gap, and Puma. Stella Artois beer bottle shown and the name mentioned.
#
# Rating: 3 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: Characters drink alcohol at bars and at home, including wine, beer, and cocktails, and are seen drunk on a few occasions. People smoke pot at home a couple of times.
#
# Rating: 3 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: How to Rob a Bank
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: Scurlock was a careless criminal and eventually came to a bad end.
#
# Rating: -1 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Although Scurlock robbed Seattle banks and eluded the authorities for five years, he was neither a genius planner nor a meticulous criminal mastermind, underscoring how ill-equipped police were to catch him. A sister described him as an adrenalin junkie.
#
# Rating: -1 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: The action takes place in the Seattle area with a largely White cast of characters.
#
# Rating: 1 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: A meth dealer is murdered. Two robbers are shot. Another takes his own life when cornered by the police.
#
# Rating: 3 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: A man enjoys walking around naked in his secluded treehouse. Home movies of full male nudity are shown.
#
# Rating: 3 out of 5
#
# Review 6:
# Label: Language
# Content: "F--k," "s--t," "ass," and "bastard."
#
# Rating: 4 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content:
# Rating: -1 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: A meth-maker gets out of that illegal business before he's arrested, then becomes a bank robber for five years. Drug use, including mushrooms and meth, is discussed.
#
# Rating: 3 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Under Paris
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: Try to save people's lives. Speak out and let yourself be heard.
#
# Rating: 2 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Knowledgeable people work hard to educate others and prevent disaster. Characters work together to stop a threat. People also show perseverance, teamwork, and communication. Leads show courage and heroism.
#
# Rating: 2 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: The leads are Argentinian French and Algerian French. Other supporting characters are White, Black, and Middle Eastern French. Women are central figures in the story. Queer sexuality is briefly represented by two women kissing and flirting, but otherwise there's no other sexuality representation.
#
# Rating: 2 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: A decent amount of violence and some gore shows characters getting bitten and eaten by large sharks. Blood spills into water, body parts float by, and people scream in terror. Characters get bitten and ripped in half, eaten whole, and ripped apart entirely. People get their legs bitten off. Injury detail with the wounds shown. Blood floats out of a scuba diver's mouth after she suffers effects of rising to the surface too quickly. People are knocked unconscious while trying to escape a shark. A picture shows the top half of a man's ripped in half body. A shark carcass is examined, its belly is sliced open, and many baby sharks spill out of the incision.
#
# Rating: 4 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: Adults briefly reference adult relationships. A couple romantically kiss.
#
# Rating: 1 out of 5
#
# Review 6:
# Label: Language
# Content: Strong language includes one instance of "s--t" and a few instances of "damn." One character gives someone the middle finger gesture.
#
# Rating: 3 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content:
# Rating: -1 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: Adults in the background are briefly shown smoking cigarettes and drinking alcohol.
#
# Rating: 1 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Pilecki's Report
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: Evil people don't need logical reasons to be behave badly. Power-hungry people will lash out violently at those who stand in their way. There is often no good rationale for prejudice. Good guys often lose the battle for decency. It's the duty of survivors of Auschwitz to tell the world about the horrors of that place.
#
# Rating: 3 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Pilecki was a Polish patriot who sacrificed his life to fight Nazi totalitarianism and later Soviet totalitarianism.
#
# Rating: 4 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: Anti-Nazi Polish patriots are equally against the new post-WWII Soviet Polish regime. The Nazis and the Soviets both rounded up and either detained or killed intellectuals, Jews, homosexuals, and other "undesirables." Polish patriots claim they do not support antisemitic views.
#
# Rating: 1 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: This is a horror film, with violent incidents taken from real life committed during and after WWII. Incidents are too numerous to list in full but they include about the worst things people could do to each other: beatings, rape, shootings, mass murders, killing of women and children, and torture. A Polish commando unit interrupts enemy troops as they put civilian men, women, and children against a wall to be shot. We see a man's fingernails torn out. A man bloodied from beatings and starving is forced to stand for hours with his hands above his head. There are reports of vile and painful medical experiments perpetrated on Auschwitz prisoners under Nazi orders, including the opening of the bellies of pregnant women without anesthetic. A Polish officer slugs Pilecki, who tries to follow his Christian conscience, and he offers his face again, explaining that he has "turned the other cheek," as Christ recommended. One dying prisoner worries the Germans will eat him after he dies, claiming he saw a mutilated body that the liver had been eaten out of. An opportunistic hungry prisoner takes the bread from the pocket of a starved, dying prisoner, claiming to someone watching that it's okay because the man "is dead already." Women and children are shot, beaten, raped, and otherwise treated brutally. Heads are seen as bloody pulps. Corpses lie in pools of blood. People dig their own graves before falling into them. Naked prisoners are beaten. Prisoners are forced to work in the cold without warm clothes. Starved prisoners are forced to walk distances carrying heavy loads of bricks.
#
# Rating: 5 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: Nonsexual nudity: naked prisoners are beaten.
#
# Rating: 1 out of 5
#
# Review 6:
# Label: Language
# Content: "F--k," "s--t," "bastard," "hell," and "damn."
#
# Rating: 4 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content:
# Rating: -1 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: Adults drink alcohol and smoke cigarettes.
#
# Rating: 3 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: The Young Wife
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: Not really a message movie, but there's a focus on having the courage to live your life for yourself and finding a balance between your goals and your friends' and family members' expectations.
#
# Rating: 2 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Celestina is overwhelmed and mildly selfish throughout the film, but she does figure out a way forward toward living her life on her own terms.
#
# Rating: 2 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: Writer-director Tayarisha Poe is a Black woman, and the racially diverse cast is led by Black actors Kiersey Clemons and Leon Bridges. But what makes this a standout on the representation front is that the characters' humanity, not their race, is at the center of the quirky, artistic, experimental story.
#
# Rating: 5 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content:
# Rating: -1 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content:
# Rating: -1 out of 5
#
# Review 6:
# Label: Language
# Content: Language includes "s--t," "ass," "f---ing," "bitch," "bulls--t," "f--k-up," "goddamn," "f--k you." Exclamatory use of "God."
#
# Rating: 4 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content:
# Rating: -1 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: Characters drink alcohol and smoke cigarettes. Cookie huffs on an oxygen tank that contains what seems to be a hallucinogenic flower.
#
# Rating: 3 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: A Part of You
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: We cannot control the actions of others. The grieving process takes time and takes shape differently for each individual. The arts can provide an important emotional outlet.
#
# Rating: 3 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Teenagers deal with complex emotions and need help from family, friends, and teachers in processing these.
#
# Rating: 3 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: The film is set in Sweden and characters speak Swedish. Two characters in a teen friend group are suggested to be gay or bisexual. Sisters are being raised by a young single mom.
#
# Rating: 2 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: A car crash is shown, and a family deals subsequently with the news of a death in the hospital. It's suggested a teenager committed suicide. People have fights, which include yelling and some pushing.
#
# Rating: 3 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: Teenagers kiss and discuss crushes. A couple is in bed together; we see them remove each other's shirts and briefly engage in what we are later told is sex. No private parts are shown beyond a woman in her underwear.
#
# Rating: 3 out of 5
#
# Review 6:
# Label: Language
# Content: "F--k," "hell," "ass," "a--hole," "damn," "freaking," "weird," "Oh my God" appear in the English subtitles.
#
# Rating: 4 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content: Converse, Apple.
#
# Rating: 1 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: Teenagers consume significant amounts of alcohol, to the point of being drunk in several scenes. It appears one has a drinking problem and uses alcohol to deal with negative emotions. Teens drink shots and beer at parties, bars, and home. They smoke cigarettes and vape. A girl uses a fake ID to enter a bar. Teens drive and ride bikes drunk.
#
# Rating: 4 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Unsinkable
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: Focuses on importance of having compassion and empathy for others, especially those who might be less fortunate than you are—or hail from different backgrounds. Courage to defend others and fight for the truth and perseverance to find the truth are also highlighted.
#
# Rating: 4 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Main characters go the extra mile to speak for the victims of the <em>Titanic</em>, especially those who were immigrants and/or of lower class than the richer guests on board who were saved primarily because of their class and status. Sen. Smith and his secretary, Maggie Malloy, combat classism, sexism, and xenophobia when bringing justice for those who couldn't defend themselves. Journalist Alaine Ricard goes through her own trials, including being beaten, to get the truth out to the papers.
#
# Rating: 4 out of 5
#
# Review 3:
# Label: Diverse Representations
# ...
#
# Rating: 4 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: Some mild verbal hostility, including using insults like "geek" (a label the main character reclaims). Several mean characters engage in bullying behavior, like posting embarrassing videos online or taping a sign that says "geek" on Harriet's back.
#
# Rating: 2 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: Teenage characters share a romantic kiss, and teenage romance is a fairly big plot point. Adult characters are flirtatious and (spoiler alert) later announce a pregnancy. Since the series is about the main character becoming a model, conventional beauty is an undercurrent. Yet the teenage romance is driven by personality, and physical appearance is not emphasized in the plot. Main character sings along to the "I'm Too Sexy" song.
#
# Rating: 2 out of 5
#
# Review 6:
# Label: Language
# Content: Insults like "geek," "loser," and "freak." Mild language like "heck" and "sexy."
#
# Rating: 2 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content: The fashion/beauty brands are all fictional. Passing mentions of brands and media like McDonald's, <em>Bend It Like Beckham</em>, Harry Potter.
#
# Rating: 1 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: Adults enjoy a drink over a meal.
#
# Rating: 1 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Eric
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: The show touches on issues like institutional racism and homophobia, drug and alcohol addiction, capitalistic greed, and the wealth disparity between social classes in America.
#
# Rating: 2 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Detective Ledroit works at rooting out injustice regardless of the great personal cost to his career and home life. Marlon Rochelle's mother never stops fighting for her son. Vincent eventually takes accountability for his actions and works at repairing his relationships.
#
# Rating: 2 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: The central family is White; the detective investigating the son's disappearance is Black. Set in 1980s New York City, the show addresses various issues facing Black and queer communities.
#
# Rating: 2 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: Some tense scenes where Vincent and his wife Cassie have fights that involve shouting and throwing things. Vincent is a combative, verbally abusive person in general. A character dies by jumping out a window (we do not see the body, but hear the screams of people on the sidewalk). There are several fistfights. A character is kicked and beaten to death; while most of the action takes place while his body is hidden behind a dumpster, the scene is still very vivid. A character plots to sell a child to a known human trafficker.
#
# Rating: 3 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: Some makeout scenes and brief depictions of simulated sex, but not a lot of skin is shown.
#
# Rating: 2 out of 5
#
# Review 6:
# Label: Language
# Content: Words like "f--k," "s--t," "damn," "bitch," and others are heard. Homophobic slurs like "f-g" and variants are used.
#
# Rating: 4 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content:
# Rating: -1 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: The lead character is constantly drinking and doing all kinds of drugs, including snorting coke and smoking crack. Cassie smokes cigarettes. Characters include drug dealers and abusers, there are several nightclub scenes full of cocktails and drinking to excess.
#
# Rating: 4 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: City Island Sings!
# Rating Age: No rating age found
#
# Review 1:
# Label: Educational Value
# Content: <em>City Island Sings!</em> introduces preschoolers to how the world around them functions, using personified objects and buildings to create an engaging educational experience.
#
# Rating: 3 out of 5
#
# Review 2:
# Label: Positive Messages
# Content: The characters embody the qualities of community stewardship and are always eager to help one another.
#
# Rating: 3 out of 5
#
# Review 3:
# Label: Positive Role Models
# Content: Characters are consistently portrayed as kind, helpful, and curious, making them excellent role models for young viewers.
#
# Rating: 4 out of 5
#
# Review 4:
# Label: Diverse Representations
# Content:
# Rating: -1 out of 5
#
# Review 5:
# Label: Violence & Scariness
# Content:
# Rating: -1 out of 5
#
# Review 6:
# Label: Sex, Romance & Nudity
# Content:
# Rating: -1 out of 5
#
# Review 7:
# Label: Language
# Content:
# Rating: -1 out of 5
#
# Review 8:
# Label: Products & Purchases
# Content:
# Rating: -1 out of 5
#
# Review 9:
# Label: Drinking, Drugs & Smoking
# Content:
# Rating: -1 out of 5
#
# Review 10:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Dancing for the Devil: The 7M TikTok Cult
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: Subjects of cults and social media are discussed. Themes of family and religion are explored.
#
# Rating: 1 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Many of the young people (like the Wilking sisters) were struggling dancers, unsure of the business side of social media, and eager to make their big career move to L.A. worth it. Robert Shinn takes advantage of their passion and exploited them through his church/company. Although the parents/families of the dancers were cut off, they were determined to help their children.
#
# Rating: 1 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: Although the focus is on a White woman and her family, many other former members are diverse in gender, race, and ethnicity. They all share their experiences, and have discussions about racism, sexism, religion, and the dark side of social media and fame. The man at the center of the controversy is of Korean descent.
#
# Rating: 2 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: Talk of sexual violence.
#
# Rating: 3 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: Some scenes show kissing. Discussions of marriage, dating, and implied sexual coercion.
#
# Rating: 1 out of 5
#
# Review 6:
# Label: Language
# Content: Language like "f--king," "hell," and "s--t."
#
# Rating: 3 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content: Social media apps TikTok and Instagram are at the center of the docuseries. Some talk of brands providing financial opportunity. Some brand logos, like Amazon, are shown.
#
# Rating: 3 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content:
# Rating: -1 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Donkey Hodie Bedtime Stories
# Rating Age: No rating age found
#
# Review 1:
# Label: Educational Value
# Content: Characters model bedtime relaxation strategies for preschoolers. The bedtime books characters read have simple social-emotional lessons, and the characters model reading strategies as a teacher would.
#
# Rating: 3 out of 5
#
# Review 2:
# Label: Positive Messages
# Content: Each of the bedtime stories focuses on a different social-emotional lesson, like helping others or using self-control.
#
# Rating: 4 out of 5
#
# Review 3:
# Label: Positive Role Models
# Content: The <em>Donkey Hodie</em> characters model healthy bedtime routines, and the characters in the bedtime "books" all have pro-social behavior.
#
# Rating: 4 out of 5
#
# Review 4:
# Label: Diverse Representations
# Content: All characters are animals. Girl and boy characters don't behave in stereotypical ways.
#
# Rating: 3 out of 5
#
# Review 5:
# Label: Violence & Scariness
# Content: One bedtime story has illustrations of dinosaurs crying; their problem is quickly solved.
#
# Rating: 1 out of 5
#
# Review 6:
# Label: Sex, Romance & Nudity
# Content:
# Rating: -1 out of 5
#
# Review 7:
# Label: Language
# Content:
# Rating: -1 out of 5
#
# Review 8:
# Label: Products & Purchases
# Content:
# Rating: -1 out of 5
#
# Review 9:
# Label: Drinking, Drugs & Smoking
# Content:
# Rating: -1 out of 5
#
# Review 10:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Fallen Idols: Nick and Aaron Carter
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: Explores alleged sexual crimes committed by a celebrity and critiques celebrity power. Series applauds survivors for coming forward, but also documents the personal ramifications for them doing so.
#
# Rating: 1 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: The subjects of the documentary, Aaron and Nick Carter, are not positive role models. The sexual assault survivors who come forward and tell their story demonstrate bravery and integrity.
#
# Rating: 2 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: Focuses on power imbalances as a wealthy, attractive, White man abuses his privilege. One of the film's interviewees is autistic and has cerebral palsy. The majority of the subjects are White and gender-balanced, with several female sexual assault survivors interviewed.
#
# Rating: 2 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: Includes detailed verbal descriptions of sexual assault and domestic violence. Dramatic reenactments of the events don't depict the alleged crimes. Survivors discuss their suffering and emotional trauma. There are several mentions of suicidal ideation.
#
# Rating: 4 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: Detailed descriptions of alleged rape involving minor teenagers. As of the docuseries' release, the alleged perpetrator is in the middle of litigation to determine consequences. Specific sexual acts are described verbally in detail. On screen, there are reenactments that imply these events without nudity. The documentary also includes pop stars wearing clingy but not revealing outfits, and discusses the sexualization of young pop stars.
#
# Rating: 4 out of 5
#
# Review 6:
# Label: Language
# Content: An autistic sexual assault survivor recounts a story of Nick Carter calling her a "retarded bitch." Otherwise, some mild profanity like "hell."
#
# Rating: 3 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content: Lots of logos present throughout (clothing brands, media companies, car companies, etc.).
#
# Rating: 3 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: Documentary details Aaron Carter's struggle with substance abuse and addiction. His substance abuse leads to bad decisions and negative consequences, and ultimately his death. On-screen Carter is cigarette smoking, drinking to excess, and noticeably impaired. There are mentions of Carter's drug-of-choice (inhaling aerosols).
#
# Rating: 3 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Jurassic World: Chaos Theory
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: It's OK to struggle with life sometimes, and it's also OK to ask for help. <a href="/articles/how-can-i-use-media-to-teach-my-kid-teamwork">Teamwork</a> can help you overcome obstacles, and it's critical to communicate what you're really thinking and feeling. Teenage friendships are important and powerful.
#
# Rating: 3 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: The teenage protagonists are courageous and try to do the right thing. They're not afraid to put themselves in danger. At the same time, they're also very emotionally vulnerable.
#
# Rating: 4 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: The teenage friends are racially diverse (with Black, Latina, Middle Eastern, Japanese, and White characters), and the voice actors' identities generally match their on-screen personas. All characters are complex and well-developed and don't fall into racial or gendered stereotypes. The teenage boy characters on the show express emotions and show vulnerability, and the girl characters have agency and take charge.
#
# Rating: 4 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: A main plot point is that dinosaurs are trying to "hunt" the teenage protagonists. Dinos often cause jump scares and flash their menacing teeth. Many scenes are ominous and suspenseful and/or action packed. Dinosaurs don't often succeed in causing an on-screen injury, but it's mentioned that a rogue dinosaur killed one of the teens from Camp Cretaceous. Characters use weapons like tranquilizers and tasers on the dinosaurs.
#
# Rating: 4 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: Based on the predecessor, expect some mild teenage romance (not present in early episodes) and clingy but not revealing outfits.
#
# Rating: 2 out of 5
#
# Review 6:
# Label: Language
# Content: Mild language like "aw crud" and "heck," and some insults like "stupid" and "dork."
#
# Rating: 2 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content:
# Rating: -1 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content:
# Rating: -1 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5
#
#
#
# Title: Tires
# Rating Age: No rating age found
#
# Review 1:
# Label: Positive Messages
# Content: This show's tone is mocking; less sophisticated viewers might miss that racism, sexism, and other "isms" are being joked about.
#
# Rating: 1 out of 5
#
# Review 2:
# Label: Positive Role Models
# Content: Will and Shane love each other and support one another when the chips are down, yet Shane ruthlessly and endlessly mocks Will as he tries to improve the auto shop's prospects and his own life. <br />
#
# Rating: 2 out of 5
#
# Review 3:
# Label: Diverse Representations
# Content: Most characters are White, working-class men who are similar to each other in terms of socioeconomic status, age, and interests; one character is female. Racial/ethnic slurs include Italian workers called "wops." <br />
#
# Rating: 1 out of 5
#
# Review 4:
# Label: Violence & Scariness
# Content: Violence is comic or in the form of jokes, like when a tire shop employee threatens to put a reporter "right through a f--king wall" with a football move.
#
# Rating: 1 out of 5
#
# Review 5:
# Label: Sex, Romance & Nudity
# Content: Expect off-color jokes, such as when a character says they're going to "tap" the women's market for tires, another agrees they will "tap that" and fist-bumps a friend; in another scene, a worker offers to give female customers a "nuru massage" (a full-body massage in which both participants are nude). Vulgar language is frequent: an (imaginary) woman is called a "fine piece of ass," a man says he'd "knock the bottom out of" an attractive woman, and a group of men rate the body parts of a woman in a photograph: "that's a perfect ass." One character mimes oral sex on another.
#
# Rating: 3 out of 5
#
# Review 6:
# Label: Language
# Content: Cursing includes "f--king," "f--k," "ass," "s--t," "assh--e." Racial/ethnic/gender/sexual identity slurs include Italian workers called "wops," women called "p---y," and "fine piece of ass," a character is referred to as a "f-g." Expect iffy words for body parts: "c--t", "t–ts," "balls," "balboas" (meaning breasts). Characters frequently call each other rude names, e.g., "d--kwad," "d--khead." <br />
#
# Rating: 4 out of 5
#
# Review 7:
# Label: Products & Purchases
# Content:
# Rating: -1 out of 5
#
# Review 8:
# Label: Drinking, Drugs & Smoking
# Content: There are jokes about a character smoking, but we don't see her smoke on-screen.
#
# Rating: 1 out of 5
#
# Review 9:
# Label: Parents Need to Know
# Content: No content found
# Rating: -1 out of 5

# %%
### FINAL SCRAPPING

# %%
# Import the necessary libraries
import requests
from bs4 import BeautifulSoup
import json

# Base URL of the website
base_url = "https://www.commonsensemedia.org"

# Function to scrape and process each URL
def scrape_and_process_url(title, url):
    # Full URL
    full_url = base_url + url

    # Determine if it's a movie or TV show
    if "/movie-reviews/" in url:
        content_type = "Movie"
    elif "/tv-reviews/" in url:
        content_type = "TV Show"
    else:
        content_type = "Unknown"

    # Fetch the content of the page
    response = requests.get(full_url)
    response.raise_for_status()  # Check if the request was successful

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extract the movie title
    movie_title = title

    # Extract the rating age using the provided CSS selector
    rating_age_element = soup.select_one("#content > div > div.one-column.row > div > div > div:nth-child(1) > div > div.row > div.col-8 > div > div.review-rating")
    rating_age = rating_age_element.get_text(strip=True) if rating_age_element else 'No rating age found'

    # Use the JavaScript path provided to find the specific content
    review_content_div = soup.select_one("#review-view-content-grid > div.row")

    # Find all child divs with the class 'content-grid-item content-grid-item--shadow'
    child_divs = review_content_div.find_all('div', class_='content-grid-item content-grid-item--shadow')

    # Extract the 'data-text' attribute, rating, and label from each child div
    reviews = []
    for idx, child_div in enumerate(child_divs, 1):
        data_text = child_div.get('data-text', 'No content found')
        data_text_cleaned = data_text.replace('<p>', '').replace('</p>', '')

        # Find the rating information within the same div
        rating_icons = child_div.select('span.rating__score i.active')
        rating = len(rating_icons) - 1  # Adjust rating by subtracting 1

        # Find the label within the same div
        label_span = child_div.select_one('span.rating__label')
        label = label_span.get_text(strip=True) if label_span else 'No label found'

        reviews.append({
            'content': data_text_cleaned,
            'rating': rating,
            'label': label
        })

    return {
        'title': movie_title,
        'content_type': content_type,
        'rating_age': rating_age,
        'reviews': reviews
    }

# Read URLs from review_links.txt
with open('review_links.txt', 'r') as file:
    lines = file.readlines()

# Process each URL and store results
all_reviews = []

for line in lines:
    line = line.strip()  # Remove any leading/trailing whitespace
    if line:
        title_part, url_part = line.split(', URL: ')
        title = title_part.replace('Title: ', '').strip()
        url = url_part.strip()
        review_data = scrape_and_process_url(title, url)
        all_reviews.append(review_data)

# Save all reviews to a JSON file
with open('all_reviews_content.json', 'w') as file:
    json.dump(all_reviews, file, indent=4)

# Optionally, print the results
for review_data in all_reviews:
    print(f"Title: {review_data['title']}")
    print(f"Content Type: {review_data['content_type']}")
    print(f"Rating Age: {review_data['rating_age']}\n")
    
    for idx, review in enumerate(review_data['reviews'], 1):
        print(f"Review {idx}:")
        print(f"Label: {review['label']}")
        print(f"Content: {review['content']}")
        print(f"Rating: {review['rating']} out of 5\n")
    print("\n")
# Out:
# Title: I Saw the TV Glow
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: Quiet on Set: The Dark Side of Kids TV
# Content Type: TV Show
# Rating Age: No rating age found
#
#
#
# Title: Zombies: The Re-Animated Series
# Content Type: TV Show
# Rating Age: No rating age found
#
#
#
# Title: Ark: The Animated Series
# Content Type: TV Show
# Rating Age: No rating age found
#
#
#
# Title: The 8 Show
# Content Type: TV Show
# Rating Age: No rating age found
#
#
#
# Title: The Magic Prank Show with Justin Willman
# Content Type: TV Show
# Rating Age: No rating age found
#
#
#
# Title: Jerrod Carmichael Reality Show
# Content Type: TV Show
# Rating Age: No rating age found
#
#
#
# Title: The Vince Staples Show
# Content Type: TV Show
# Rating Age: No rating age found
#
#
#
# Title: The Addams Family (Animated TV Series)
# Content Type: TV Show
# Rating Age: No rating age found
#
#
#
# Title: Catfish: The TV Show
# Content Type: TV Show
# Rating Age: No rating age found
#
#
#
# Title: Spider-Man (1981 TV Show)
# Content Type: TV Show
# Rating Age: No rating age found
#
#
#
# Title: Ape Star
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: Ernest & Celestine
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: Ernest and Celestine: A Trip to Gibberitia
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: Moomins and the Winter Wonderland
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: Yellow Submarine
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: Chicken Run
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: Fantastic Mr. Fox
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: Felix and the Hidden Treasure
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: The Garfield Movie
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: James and the Giant Peach
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: The Nightmare Before Christmas
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: Song of the Sea
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: Strike
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: Wallace & Gromit
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: 10 Lives
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: Arlo the Alligator Boy
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: Howl's Moving Castle
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: Leo
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: Marcel the Shell with Shoes On
# Content Type: Movie
# Rating Age: No rating age found
#
#
#
# Title: A Monster in Paris
# Content Type: Movie
# Rating Age: No rating age found

# %%
##### CURRRENT JSON DATA

# %%
import json
import pandas as pd

# Load the JSON data from the file
with open('all_reviews_content.json', 'r') as file:
    all_reviews = json.load(file)

# Create a list to store the data for the table
table_data = []

# Iterate through the JSON data and extract the necessary information
for review_data in all_reviews:
    name = review_data['title']
    content_type = review_data['content_type']
    rating_age = review_data['rating_age']
    table_data.append({'Name': name, 'Type': content_type, 'Age Classification': rating_age})

# Create a DataFrame from the table data
df = pd.DataFrame(table_data)

# Sort the DataFrame by 'Type' and 'Age Classification'
df_sorted = df.sort_values(by=['Type', 'Age Classification'])

# Display the sorted DataFrame
ionally, save the sorted DataFrame to a CSV file
df_sorted.to_csv('sorted_reviews_table.csv', index=False)
# Out:
#   Cell In[5], line 25
#     ionally, save the sorted DataFrame to a CSV file
#                                                     ^
# SyntaxError: invalid syntax

# %%
import json
import pandas as pd
import re

# Load JSON data from the file
with open('all_reviews_content.json', 'r') as file:
    data = json.load(file)

# Process the data to create a structured DataFrame
processed_data = []
for entry in data:
    type_ = entry['content_type']
    age_classification = re.sub(r'\D', '', entry['rating_age'])  # Remove non-numeric characters
    processed_data.append({
        'Title': entry['title'],
        'Type': type_,
        'Age Classification': int(age_classification)  # Convert to integer for proper sorting
    })

# Create a DataFrame from the processed data
df = pd.DataFrame(processed_data)

# Count the number of movies and TV shows per age classification
counts = df.groupby(['Type', 'Age Classification']).size().reset_index(name='Count')

# Sort by Type and Age Classification
sorted_counts = counts.sort_values(by=['Type', 'Age Classification'])

# Add a column for the sum of counts per type
sorted_counts['Total Count per Type'] = sorted_counts.groupby('Type')['Count'].transform('sum')

# Display the final table
print(sorted_counts)

# Optionally, save the final table to a CSV file
sorted_counts.to_csv('sorted_counts.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 import json
# ----> 2 import pandas as pd
#       3 import re
#       5 # Load JSON data from the file
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/__init__.py:11
#       9 for _dependency in _hard_dependencies:
#      10     try:
# ---> 11         __import__(_dependency)
#      12     except ImportError as _e:  # pragma: no cover
#      13         _missing_dependencies.append(f"{_dependency}: {_e}")
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/__init__.py:157
#     155 from . import fft
#     156 from . import polynomial
# --> 157 from . import random
#     158 from . import ctypeslib
#     159 from . import ma
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/random/__init__.py:180
#     126 __all__ = [
#     127     'beta',
#     128     'binomial',
#    (...)
#     176     'zipf',
#     177 ]
#     179 # add these for module-freeze analysis (like PyInstaller)
# --> 180 from . import _pickle
#     181 from . import _common
#     182 from . import _bounded_integers
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/random/_pickle.py:1
# ----> 1 from .mtrand import RandomState
#       2 from ._philox import Philox
#       3 from ._pcg64 import PCG64, PCG64DXSM
#
# File numpy/random/mtrand.pyx:19, in init numpy.random.mtrand()
#
# File <frozen importlib._bootstrap>:398, in parent(self)
#
# KeyboardInterrupt:
