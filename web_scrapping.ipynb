# %%
import requests
from bs4 import BeautifulSoup
import json

# Base URL pattern for paginated search results
base_url = "https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/{}/sort/date-desc"

# List of labels we are interested in extracting
rating_labels = [
    "Violence & Scariness", "Language", "Sex, Romance & Nudity", "Products & Purchases",
    "Drinking, Drugs & Smoking", "Positive Role Models", "Positive Messages", 
    "Educational Value", "Diverse Representations"
]

# Function to scrape titles and links from a single page
def scrape_titles_and_links(page_number):
    url = base_url.format(page_number)
    print(f"Scraping page: {url}")
    
    response = requests.get(url)
    response.raise_for_status()
    
    soup = BeautifulSoup(response.content, 'html.parser')
    results = soup.select('div.site-search-teaser')  # Select each review teaser block

    titles_and_links = []

    # Loop through each result to extract title and link
    for result in results:
        title_element = result.select_one('h3.review-title a.link--title')
        if title_element:
            title = title_element.get_text(strip=True)
            link = "https://www.commonsensemedia.org" + title_element['href']  # Full URL
            titles_and_links.append({
                'title': title,
                'link': link
            })

    return titles_and_links

# Function to scrape the detailed review information from the TV show page
def scrape_review_details(review_url):
    print(f"Scraping review page: {review_url}")
    
    response = requests.get(review_url)
    response.raise_for_status()
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the release year
    product_summary = soup.select_one('div.review-product-summary')
    if product_summary:
        year_elements = product_summary.find_all('span')
        release_year = year_elements[-1].get_text(strip=True) if year_elements else 'No release year found'
    else:
        release_year = 'No release year found'
    
    # Extract the age rating
    age_rating_element = soup.select_one('div.review-rating span.rating__age')
    age_rating = age_rating_element.get_text(strip=True) if age_rating_element else 'No age rating found'
    
    # Extract the details for all the rating criteria (e.g., Violence & Scariness, Language, etc.)
    details = []
    
    # Locate all buttons containing the rating information
    buttons = soup.select('button.rating--interactive')

    for button in buttons:
        # Extract the label (e.g., "Violence & Scariness")
        label_element = button.select_one('span.rating__label')
        if label_element:
            label_text = label_element.get_text(strip=True)
            # If the label is one of the ones we care about
            if label_text in rating_labels:
                # Count the number of active dots (rating), subtract 1 if needed
                active_dots = max(len(button.select('span.rating__score i.active')) - 1, 0)
                
                # Extract the description
                description_element = button.select_one('span.rating__teaser p')
                description = description_element.get_text(strip=True) if description_element else 'No description found'
                
                # Append the result
                details.append({
                    'label': label_text,
                    'rating': active_dots,
                    'description': description
                })
    
    return {
        'release_year': release_year,
        'age_rating': age_rating,
        'details': details
    }

# Function to scrape multiple pages
def scrape_all_pages(last_page=50):
    page_number = 1
    all_reviews = []

    while page_number <= last_page:
        titles_and_links = scrape_titles_and_links(page_number)
        
        if not titles_and_links:
            print(f"No more results found on page {page_number}. Stopping.")
            break
        
        # For each title and link, follow the link and scrape the review details
        for item in titles_and_links:
            review_details = scrape_review_details(item['link'])
            review_data = {
                'title': item['title'],
                'link': item['link'],
                'release_year': review_details['release_year'],
                'age_rating': review_details['age_rating'],
                'details': review_details['details']
            }
            all_reviews.append(review_data)
        
        page_number += 1

    return all_reviews

# Scrape all pages and get the review details
all_reviews_data = scrape_all_pages(last_page=5)  # You can adjust the last_page number

# Save the results to a JSON file
output_file = "detailed_reviews_with_ratings.json"
with open(output_file, 'w') as file:
    json.dump(all_reviews_data, file, indent=4)

print(f"Data saved to {output_file}")
# Out:
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/1/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/barbie-and-stacie-to-the-rescue
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/future-chicken
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/zuhu-ka-zalzala
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pokemon-horizons
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/hot-wheels-lets-race
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/megamind-rules
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/iwaju
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/snoopy-presents-welcome-home-franklin
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/caillou-0
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/beas-block
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bluey-book-reads
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rock-paper-scissors
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/heroes-of-zero
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lyla-in-the-loop
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mighty-bheems-playtime
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/brown-and-friends
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pokemon-concierge
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rocket-saves-the-day
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/craig-before-the-creek
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/catch-teenieping
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/2/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kibaoh-klashers
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/sea-of-love
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mickeys-christmas-tales
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-heroic-quest-of-the-valiant-prince-ivandoe
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/young-david
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/unicorn-academy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/strawberry-shortcakes-perfect-holiday
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lego-marvel-avengers-code-red
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lil-stompers
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/chip-chilla
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/superbuns
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/jessicas-big-little-world
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/fright-krewe
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mickey-and-friends-trick-or-treats
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/elemon
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/tiny-toons-looniversity
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pokemon-to-be-a-pokemon-master
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/adventure-time-fionna-cake
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/polly-pocket-sparkle-cove-adventure
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/snoopy-presents-one-of-a-kind-marcie
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/3/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lego-disney-princess-the-castle-quest
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lloyd-of-the-flies
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/om-nom-stories
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/zombies-the-re-animated-series-shorts
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/supa-team-4
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/morphle-3d
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/moley
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/my-adventures-with-superman
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/wake-up-carlo
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kizazi-moto-generation-fire
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/barbie-a-touch-of-magic
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/when-duck-met-goose
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/haileys-on-it
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/my-little-pony-bridlewoodstock
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/ninjago-dragons-rising
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/edmond-and-lucy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dino-pops
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/gremlins-secrets-of-the-mogwai
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lego-dreamzzz
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kitti-katz
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/4/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/peppa-pig-cruise-special
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/star-wars-young-jedi-adventures
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/frog-and-toad
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/we-lost-our-human
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/zizi-and-hannibal
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pat-the-dog
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-enchanted-village-of-pinocchio
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/sago-mini-friends-earth-day-special-treasure-it
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rev-and-roll
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/hanni-and-the-wild-woods
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/storytime-with-ms-booksy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/thomas-friends-the-mystery-of-lookout-mountain
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/eva-the-owlet
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kiya-the-kimoja-heroes
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kiff
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bossy-bear
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/karate-sheep
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mighty-ducks-the-animated-series
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/quack-pack
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/fantastic-four-worlds-greatest-heroes
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/5/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/marvels-avengers-secret-wars-shorts
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mickeys-mousekersize
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/muppet-babies-play-date
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mickey-mouse-hot-diggity-dog-tales
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/marvels-moon-girl-and-devil-dinosaur
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/my-dad-the-bounty-hunter
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/work-it-out-wombats
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rubble-crew
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/princess-power
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/jam-van
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/spongebob-square-pants-presents-the-tidal-zone
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/superkitties
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/city-island
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/sonic-prime
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/gudetama-an-eggcellent-adventure
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/boss-baby-christmas-bonus
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mighty-express-mighty-trains-race
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-wingfeather-saga
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/scribbles-and-ink
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pretzel-and-the-puppies-holiday-special-merry-muttgomery
# Data saved to detailed_reviews_with_ratings.json

# %%
import requests
from bs4 import BeautifulSoup
import json

# Base URL pattern for paginated search results
base_url = "https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/{}/sort/date-desc"

# List of labels we are interested in extracting
rating_labels = [
    "Violence & Scariness", "Language", "Sex, Romance & Nudity", "Products & Purchases",
    "Drinking, Drugs & Smoking", "Positive Role Models", "Positive Messages", 
    "Educational Value", "Diverse Representations"
]

# Function to scrape titles and links from a single page
def scrape_titles_and_links(page_number):
    url = base_url.format(page_number)
    print(f"Scraping page: {url}")
    
    response = requests.get(url)
    response.raise_for_status()
    
    soup = BeautifulSoup(response.content, 'html.parser')
    results = soup.select('div.site-search-teaser')  # Select each review teaser block

    titles_and_links = []

    # Loop through each result to extract title and link
    for result in results:
        title_element = result.select_one('h3.review-title a.link--title')
        if title_element:
            title = title_element.get_text(strip=True)
            link = "https://www.commonsensemedia.org" + title_element['href']  # Full URL
            titles_and_links.append({
                'title': title,
                'link': link
            })

    # Check if there's a "next page" link
    next_page_element = soup.select_one('li.pagination__next')
    has_next_page = next_page_element is not None

    return titles_and_links, has_next_page

# Function to scrape the detailed review information from the TV show page
def scrape_review_details(review_url):
    print(f"Scraping review page: {review_url}")
    
    response = requests.get(review_url)
    response.raise_for_status()
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract the release year
    product_summary = soup.select_one('div.review-product-summary')
    if product_summary:
        year_elements = product_summary.find_all('span')
        release_year = year_elements[-1].get_text(strip=True) if year_elements else 'No release year found'
    else:
        release_year = 'No release year found'
    
    # Extract the age rating
    age_rating_element = soup.select_one('div.review-rating span.rating__age')
    age_rating = age_rating_element.get_text(strip=True) if age_rating_element else 'No age rating found'
    
    # Extract the details for all the rating criteria (e.g., Violence & Scariness, Language, etc.)
    details = []
    
    # Locate all buttons containing the rating information
    buttons = soup.select('button.rating--interactive')

    for button in buttons:
        # Extract the label (e.g., "Violence & Scariness")
        label_element = button.select_one('span.rating__label')
        if label_element:
            label_text = label_element.get_text(strip=True)
            # If the label is one of the ones we care about
            if label_text in rating_labels:
                # Count the number of active dots (rating), subtract 1 if needed
                active_dots = max(len(button.select('span.rating__score i.active')) - 1, 0)
                
                # Extract the description
                description_element = button.select_one('span.rating__teaser p')
                description = description_element.get_text(strip=True) if description_element else 'No description found'
                
                # Append the result
                details.append({
                    'label': label_text,
                    'rating': active_dots,
                    'description': description
                })
    
    return {
        'release_year': release_year,
        'age_rating': age_rating,
        'details': details
    }

# Function to scrape multiple pages
def scrape_all_pages():
    page_number = 1
    all_reviews = []
    has_next_page = True

    while has_next_page:
        titles_and_links, has_next_page = scrape_titles_and_links(page_number)
        
        if not titles_and_links:
            print(f"No more results found on page {page_number}. Stopping.")
            break
        
        # For each title and link, follow the link and scrape the review details
        for item in titles_and_links:
            review_details = scrape_review_details(item['link'])
            review_data = {
                'title': item['title'],
                'link': item['link'],
                'release_year': review_details['release_year'],
                'age_rating': review_details['age_rating'],
                'details': review_details['details']
            }
            all_reviews.append(review_data)
        
        page_number += 1

    return all_reviews

# Scrape all pages and get the review details
all_reviews_data = scrape_all_pages()

# Save the results to a JSON file
output_file = "detailed_reviews_with_ratings.json"
with open(output_file, 'w') as file:
    json.dump(all_reviews_data, file, indent=4)

print(f"Data saved to {output_file}")
# Out:
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/1/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/barbie-and-stacie-to-the-rescue
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/future-chicken
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/zuhu-ka-zalzala
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pokemon-horizons
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/hot-wheels-lets-race
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/megamind-rules
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/iwaju
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/snoopy-presents-welcome-home-franklin
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/caillou-0
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/beas-block
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bluey-book-reads
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rock-paper-scissors
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/heroes-of-zero
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lyla-in-the-loop
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mighty-bheems-playtime
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/brown-and-friends
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pokemon-concierge
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rocket-saves-the-day
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/craig-before-the-creek
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/catch-teenieping
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/2/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kibaoh-klashers
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/sea-of-love
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mickeys-christmas-tales
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-heroic-quest-of-the-valiant-prince-ivandoe
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/young-david
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/unicorn-academy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/strawberry-shortcakes-perfect-holiday
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lego-marvel-avengers-code-red
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lil-stompers
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/chip-chilla
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/superbuns
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/jessicas-big-little-world
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/fright-krewe
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mickey-and-friends-trick-or-treats
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/elemon
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/tiny-toons-looniversity
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pokemon-to-be-a-pokemon-master
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/adventure-time-fionna-cake
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/polly-pocket-sparkle-cove-adventure
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/snoopy-presents-one-of-a-kind-marcie
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/3/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lego-disney-princess-the-castle-quest
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lloyd-of-the-flies
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/om-nom-stories
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/zombies-the-re-animated-series-shorts
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/supa-team-4
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/morphle-3d
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/moley
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/my-adventures-with-superman
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/wake-up-carlo
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kizazi-moto-generation-fire
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/barbie-a-touch-of-magic
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/when-duck-met-goose
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/haileys-on-it
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/my-little-pony-bridlewoodstock
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/ninjago-dragons-rising
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/edmond-and-lucy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dino-pops
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/gremlins-secrets-of-the-mogwai
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lego-dreamzzz
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kitti-katz
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/4/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/peppa-pig-cruise-special
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/star-wars-young-jedi-adventures
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/frog-and-toad
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/we-lost-our-human
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/zizi-and-hannibal
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pat-the-dog
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-enchanted-village-of-pinocchio
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/sago-mini-friends-earth-day-special-treasure-it
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rev-and-roll
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/hanni-and-the-wild-woods
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/storytime-with-ms-booksy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/thomas-friends-the-mystery-of-lookout-mountain
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/eva-the-owlet
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kiya-the-kimoja-heroes
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kiff
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bossy-bear
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/karate-sheep
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mighty-ducks-the-animated-series
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/quack-pack
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/fantastic-four-worlds-greatest-heroes
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/5/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/marvels-avengers-secret-wars-shorts
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mickeys-mousekersize
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/muppet-babies-play-date
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mickey-mouse-hot-diggity-dog-tales
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/marvels-moon-girl-and-devil-dinosaur
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/my-dad-the-bounty-hunter
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/work-it-out-wombats
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rubble-crew
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/princess-power
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/jam-van
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/spongebob-square-pants-presents-the-tidal-zone
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/superkitties
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/city-island
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/sonic-prime
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/gudetama-an-eggcellent-adventure
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/boss-baby-christmas-bonus
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mighty-express-mighty-trains-race
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-wingfeather-saga
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/scribbles-and-ink
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pretzel-and-the-puppies-holiday-special-merry-muttgomery
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/6/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/interrupting-chicken-holiday-special-a-chicken-carol
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bananya
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/snoopy-show-holiday-special-happiness-is-the-gift-of-giving
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/sesame-street-the-nutcracker
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/reindeer-in-here
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/action-pack-saves-christmas
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mickey-saves-christmas
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/my-little-pony-winter-wishday
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/sago-mini-kids-happy-thankful-day
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/interrupting-chicken
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/jurassic-world-camp-cretaceous-hidden-adventure
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/teletubbies-2022
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/transformers-earthspark
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/zootopia
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/slumberkins
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/teletubbies-lets-go
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/monster-high-0
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/daniel-spellbound
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/tales-of-the-jedi
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/little-angel
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/7/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lol-surprise-winter-fashion-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-eggventurers
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/oni-thunder-gods-tale
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/batwheels
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-nutty-boy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/spirit-rangers
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/oddballs
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/abominable-and-the-invisible-city
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rosies-rules
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/jelly-ben-pogo
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/firebuds
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/minions-more
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/secret-origin-of-the-batwheels
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/sago-mini-friends
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/cars-on-the-road
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/arthurs-first-day
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/superellas
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/doggyland
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/deepa-anoop
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/snoopy-presents-lucys-school
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/8/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/hamster-gretel
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lego-star-wars-summer-vacation
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/super-giant-robot-brothers
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/big-tree-city
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/chibiverse
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bugs-bunny-builders
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kung-fu-panda-the-dragon-knight
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/caillou-rosie-the-giant
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/duck-goose
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/peppas-club
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/baymax
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/me-mickey
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/chip-and-potato-chips-holiday
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/hobbykids-adventures
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/eureka-0
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/daniel-tigers-neighborhood-daniel-visits-a-new-neighborhood
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dead-end-paranormal-park
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lovely-little-farm
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/faces-music-party
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mighty-little-bheem-i-love-taj-majal
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/9/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mira-royal-detective-the-mystery-of-the-royal-flight
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/my-little-pony-make-your-mark
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-boss-baby-back-in-the-crib
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mira-royal-detective-mikku-and-chikkus-hometown-mystery
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/be-cool-scooby-doo
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/snoopy-presents-to-mom-and-dad-with-love
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mira-royal-detective-the-mystery-of-the-legendary-sword
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/arpo
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pocoyo-specials
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pocoyo-disco
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/cyberchase-buzz-and-the-tree
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/samurai-rabbit-the-usagi-chronicles
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/vlad-and-niki
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/battle-kitty
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/elinor-wonders-why-a-wonderful-journey
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/ice-age-scrat-tales
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-creature-cases
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pinecone-pony
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/barbie-it-takes-two
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/my-little-pony-tell-your-tale
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/10/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-fairly-oddparents-fairly-odder
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/transformers-botbots
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-wonderful-spring-of-mickey-mouse
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/karmas-world-music-videos
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-proud-family-louder-and-prouder
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-wonderful-winter-of-mickey-mouse
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-cuphead-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/big-nate
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pretzel-and-the-puppies
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/alices-wonderland-bakery
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rise-up-sing-out
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/looney-tunes-cartoons-valentines-extwavaganza
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/angry-birds-summer-madness
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/supernatural-academy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/el-deafo
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/we-baby-bears
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-guava-juice-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/word-party-presents-math
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/babble-bop
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dragons-the-nine-realms
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/11/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/starbeam-beaming-in-the-new-year
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/blippi-wonders
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/supa-strikas-rookie-season
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/shaun-the-sheep-the-flight-before-christmas
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/odo
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mickey-and-minnie-wish-upon-a-christmas
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/charlies-colorforms-city-snowy-stories
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/5-more-sleeps-til-christmas
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/madagascar-a-little-wild-holiday-goose-chase
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dragons-rescue-riders-heroes-of-the-sky
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/robin-robin
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/harriet-the-spy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dogs-in-space
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/johnny-test-ultimate-meatloaf-quest
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/olaf-presents
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/star-trek-prodigy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/maya-and-the-three
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/aquaman-king-of-atlantis
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/karmas-world
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/sharkdogs-fintastic-halloween
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/12/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/a-tale-dark-grimm
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lego-star-wars-terrifying-tales
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-ghost-and-molly-mcgee
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/yabba-dabba-dinosaurs
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/wolfboy-and-the-everything-factory
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-croods-family-tree
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/strawberry-shortcake-berry-in-the-big-city
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/growing-with-lottie-dottie
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lucas-the-spider
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/do-re-mi
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/he-man-and-the-masters-of-the-universe-0
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/a-storybots-space-adventure
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mush-mush-and-the-mushables
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/little-ellen
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/thomas-friends-all-engines-go
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-smurfs-0
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lego-monkie-kid
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pepper-ann
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/octonauts-above-and-beyond
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/sharkdog
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/13/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/adventure-time-distant-lands-wizard-city
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dug-days
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/i-heart-arlo
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mickey-mouse-funhouse
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/looney-tunes-cartoons-back-to-school-special
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/descendants-the-royal-wedding
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/marvels-spidey-and-his-amazing-friends
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/furry-friends-forever-elmo-gets-a-puppy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lellobee-city-farm
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/centaurworld
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/chip-n-dale-park-life
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/johnny-test-2021
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/middlemost-post
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-patrick-star-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/monsters-at-work
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/tom-and-jerry-in-new-york
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-beatbuds-lets-jam
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/super-monsters-once-upon-a-rhyme
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rugrats-0
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/adventure-time-distant-lands-together-again
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/14/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-fury-files
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-last-kids-on-earth-happy-apocalypse-to-you
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bluey-easter
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/ewoks
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/elliott-from-earth
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-runaway-bunny
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/super-sema
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/city-of-ghosts
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/miniforce-super-dino-power
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kamp-koral-spongebobs-under-years
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rhymes-through-times
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-snoopy-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kid-cosmic
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/go-dog-go
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pixar-popcorn
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mighty-little-bheem-kite-festival
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/squish
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pui-pui-molcar
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/gabbys-dollhouse
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/cartoonito-shorts
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/15/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/oggy-oggy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/a-go-go-cory-carson-christmas
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/a-trash-truck-christmas
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/baby-sharks-big-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lets-go-luna-lunas-christmas-around-the-world
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/esme-roy-holiday-spiritsnow-worries
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/onyx-monster-mysteries
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/spirit-riding-free-ride-along-adventure
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/super-monsters-santas-super-monster-helpers
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mighty-express-a-mighty-christmas
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/stillwater
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/captain-underpants-mega-blissmas
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pinkfong-wonderstar
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bugs-bunnys-24-carrot-holiday-special
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/chico-bon-bon-and-the-very-berry-holiday
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-three-wise-men
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dragons-rescue-riders-huttsgalor-holiday
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/animaniacs-0
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/trollstopia
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-wonderful-world-of-mickey-mouse
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/16/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lego-star-wars-holiday-special
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/an-arthur-thanksgiving
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/doug-unplugs
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/trash-truck
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-mighty-ones
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/my-little-pony-pony-life
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pikwik-pack
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-monster-at-the-end-of-this-story
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/once-upon-a-snowman
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/zombies-addisons-moonstone-mystery
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/santiago-of-the-seas
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bug-diaries-halloween-bug-a-boo
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rainbow-high
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mighty-express
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/jurassic-world-camp-cretaceous
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mo-willems-storytime-shorts
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/madagascar-a-little-wild
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/elinor-wonders-why
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/alien-tv
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mias-magic-playground
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/17/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-fungies
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/daniel-tigers-neighborhood-wont-you-sing-along-with-me
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/elmos-playdate-scavenger-hunt
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/curious-george-0
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-epic-tale-of-captain-underpants-in-space
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/adventure-time-distant-lands-bmo
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rhyme-time-town
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/marvel-battleworld-mystery-of-the-thanostones
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-scooby-doo-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/chibi-tiny-tales
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/tobot-galaxy-detectives
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/looney-tunes-cartoons
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/chico-bon-bon-monkey-with-a-toolbelt
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-paper-girls-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/remy-and-boo
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/helpsters-help-you
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/ollies-pack
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/spirit-riding-free-riding-academy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/starbeam
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/buddi
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/18/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mira-royal-detective
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/shaun-the-sheep-adventures-from-mossy-bottom
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/jojo-gran-gran
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/xavier-riddle-and-the-secret-movie-i-am-madam-president
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/jessy-nessy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/carmen-sandiego-to-steal-or-not-to-steal
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mighty-little-bheem-festival-of-colors
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dog-loves-books
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/101-dalmatian-street
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/toca-life-stories
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/glitch-techs
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/thundercats-roar
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/captain-underpants-epic-choice-o-rama
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pete-the-cat-a-very-groovy-valentines-day
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/deer-squad
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/short-circuit
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-adventures-of-paddington
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/its-pony
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kipo-and-the-age-of-wonderbeasts
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-owl-house
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/19/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/go-go-cory-carson
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/powerbirds
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mr-magoo-2019
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lassie-2014
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/fast-furious-spy-racers
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/max-maestro
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/steven-universe-future
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/spirit-riding-free-spirit-of-christmas
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/clifford-the-big-red-dog-0
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/nature-cat-a-nature-carol
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/true-winter-wishes
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dino-girl-gauko
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/costume-quest-heroes-on-holiday
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/forky-asks-a-question
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/blues-clues-you
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/xavier-riddle-and-the-secret-museum
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-rocketeer
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/green-eggs-and-ham
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lol-surprise-winter-disco
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/hello-ninja
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/20/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/true-grabbleapple-harvest
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/helpsters
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/snoopy-in-space
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/if-you-give-a-mouse-a-pumpkin
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mighty-little-bheem-diwali
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-casagrandes
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/super-dinosaur
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dragons-rescue-riders
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/power-players
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lego-jurassic-world-legend-of-isla-nublar
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bluey
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/ricky-zoom
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/middle-school-moguls
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/archibalds-next-big-thing
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mighty-mike
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/invader-zim-enter-the-florpus
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/spirit-riding-free-pony-tales
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/infinity-train
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/twelve-forever
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/norman-picklestripes
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/21/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/wheres-waldo-2019
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/molly-of-denali
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/spongebobs-big-birthday-blowout
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mao-mao-heroes-of-pure-heart
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/scooby-doo-and-guess-who
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/little-baby-bum
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lego-city-adventures
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-bravest-knight
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/amphibia
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/tots
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/44-cats
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/chip-and-potato
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/super-monsters-furever-friends
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bug-diaries
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mighty-little-bheem
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/ultraman
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/victor-and-valentino
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/charlies-colorforms-city
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kiri-lou
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/yoohoo-to-the-rescue
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/22/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dc-super-hero-girls-0
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/costume-quest
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/corn-peg
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bubu-and-the-little-owls
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/moon-and-me
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/care-bears-unlock-the-magic
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/true-happy-hearts-day
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rainbow-butterfly-unicorn-kitty
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/gigantosaurus
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/carmen-sandiego
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/marvel-rising-chasing-ghosts
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/morphle
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/transformers-rescue-bots-academy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bakugan-battle-planet
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/milo-murphys-law-the-phineas-and-ferb-effect
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/young-justice-outsiders
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-monchhichi-tribe
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mixed-nutz
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/abby-hatcher
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pinky-malinky
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/23/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/elf-pets-santas-st-bernards-save-christmas
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-doc-mcstuffins-christmas-special
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/spacebob-merrypants
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lets-go-luna
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pete-the-cat-a-very-groovy-christmas
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/creative-galaxy-artys-holiday-masterpiece
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kung-fu-panda-the-paws-of-destiny
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/she-ra-and-the-princesses-of-power
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/butterbeans-cafe
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/minecraft-story-mode
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rainbow-rangers
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/calico-critters
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lego-star-wars-all-stars
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/robozuna
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/star-wars-resistance
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/marvel-rising-secret-warriors
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/beccas-bunch
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dragon-pilot
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/hilda
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pete-the-cat
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/24/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rise-of-the-teenage-mutant-ninja-turtles
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-dragon-prince
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-polos
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/total-dramarama
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/transformers-cyberverse
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/martin-morning
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lego-ninjago-masters-of-spinjitzu-hunted
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/marvel-rising-initiation
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-chocolix
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/esme-roy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mega-man-fully-charged
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/jell-o-wobz
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/cupcake-and-dino-general-services
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-fox-badger-family
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mily-miss-questions
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/fancy-nancy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/summer-camp-island
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-epic-tales-of-captain-underpants
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/polly-pocket
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/atchoo
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/25/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/harvey-street-kids
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/big-city-greens
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/true-magical-friends
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/true-wonderful-wishes
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/diy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/legend-of-the-three-caballeros
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/treehouse-detectives
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/music-lullabies
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/lego-ninjago-masters-of-spinjitzu-possession
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/darwin-newts
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-adventures-of-rocky-and-bullwinkle
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/canticos
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/luo-bao-bei
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/barbie-dreamhouse-adventures
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/little-big-awesome
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/nate-is-late
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/spy-kids-mission-critical
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/littlest-pet-shop-a-world-of-our-own
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-boss-baby-back-in-business
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pablo
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/26/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/craig-of-the-creek
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/muppet-babies
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/apple-onion
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pinkalicious-peterrific
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-stinky-dirty-valentines-day-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/llama-llama
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/cleo-cuquin
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-adventures-of-kid-danger
# ...
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/catdog
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/franklin
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bear-in-the-big-blue-house
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/breakfast-with-bear
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/men-in-black-the-series
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/wimzies-house
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/caillou
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/101-dalmatians
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kipper
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/recess
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-weird-al-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/cow-and-chicken
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/johnny-bravo
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-angry-beavers
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kablam
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/hey-arnold
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/beast-wars-transformers
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dragon-ball-z
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/69/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/jumanji-the-animated-series
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/blues-clues
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-incredible-hulk-1996
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/superman-the-animated-series
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/arthur
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dexters-laboratory
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/little-bear
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/freakazoid
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/pinky-and-the-brain
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/timon-pumbaa
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/happily-ever-after-fairy-tales-for-every-child
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/hercules
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-sylvester-tweety-mysteries
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/spider-man
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/aaahh-real-monsters
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/gargoyles
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/iron-man-1994
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/fantastic-four
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/magic-adventures-of-mumfie
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-magic-school-bus
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/70/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/aladdin
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/street-sharks
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-busy-world-of-richard-scarry
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/where-on-earth-is-carmen-sandiego
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/veggietales
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/biker-mice-from-mars
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-new-adventures-of-madeline
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rockos-modern-life
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/animaniacs
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/swat-kats-the-radical-squadron
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-adventures-of-sonic-the-hedgehog
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/2-stupid-dogs
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bonkers
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/x-men
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/toonheads
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/conan-the-adventurer
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-addams-family-animated-tv-series
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-little-mermaid
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/batman-the-animated-series
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/goof-troop
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/71/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/fievels-american-tales
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bananas-in-pyjamas
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/shelley-duvalls-bedtime-stories
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/winnie-the-pooh-and-christmas-too
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-adventures-of-tintin
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/darkwing-duck
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/doug
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rugrats
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-ren-stimpy-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/casper-friends
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/tom-and-jerry-kids-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/tiny-toon-adventures
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bobbys-world
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/talespin
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mother-goose-stories
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dink-the-little-dinosaur
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-legend-of-zelda
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/super-mario-bros-super-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/chip-n-dale-rescue-rangers
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/babar
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/72/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/garfield-and-friends
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/a-pup-named-scooby-doo
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-new-adventures-of-winnie-the-pooh
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/hbo-storybook-musicals
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/fireman-sam
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/ducktales
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/bravestarr
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/fraggle-rock-the-animated-series
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dennis-the-menace
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/my-little-pony-n-friends
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-adventures-of-the-galaxy-rangers
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-real-ghostbusters
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/popples
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/ghostbusters-the-animated-series
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-flintstone-kids
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/paw-paws
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/jem-and-the-holograms
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/adventures-of-the-gummi-bears
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/she-ra-princess-of-power
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/robotech
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/73/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/thundercats-1980s
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/thomas-friends
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/transformers
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-snorks
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/voltron-lion-force
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/voltron
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/heathcliff
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/danger-mouse
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-wind-in-the-willows
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dungeons-dragons
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/inspector-gadget
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/gi-joe-a-real-american-hero
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-littles
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/he-man-and-the-masters-of-the-universe
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-dukes
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/shirt-tales
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/postman-pat
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/spider-man-1981-tv-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-smurfs
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/heathcliff-and-marmaduke
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/74/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/kwicky-koala
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/spider-man-and-his-amazing-friends
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/richie-rich
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/thundarr-the-barbarian
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/spider-woman
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/scooby-doo-and-scrappy-doo
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-super-globetrotters
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/star-blazers
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-story-of-the-faithful-wookiee
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/captain-caveman-and-the-teen-angels
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/laff-a-lympics
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dynomutt
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/jabberjaw
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/valley-of-the-dinosaurs
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/hong-kong-phooey
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/super-friends
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/inch-high-private-eye
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/speed-buggy
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/wait-till-your-father-gets-home
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/fat-albert-and-the-cosby-kids
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/75/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-amazing-chan-and-the-chan-clan
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-pebbles-and-bamm-bamm-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/funky-phantom
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/help-its-the-hair-bear-bunch
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/josie-and-the-pussycats
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/cattanooga-cats
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/dastardly-and-muttley
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/scooby-doo-where-are-you
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-perils-of-penelope-pitstop
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-pink-panther
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-archie-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-adventures-of-young-gulliver
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/wacky-races
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/speed-racer
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/aquaman
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-herculoids
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-impossibles
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/batfink
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/atom-ant
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-secret-squirrel-show
# Scraping page: https://www.commonsensemedia.org/search/category/tv/genre/kids-animation-52/page/76/sort/date-desc
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/tom-and-jerry
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/underdog
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/jonny-quest
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/magilla-gorilla
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/astro-boy-1960s
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-jetsons
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/top-cat
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-yogi-bear-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-dick-tracy-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-mr-magoo-show
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/the-flintstones
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/popeye
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/mr-peabody-sherman
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/rocky-bullwinkle
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/felix-the-cat
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/quick-draw-mcgraw
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/huckleberry-hound
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/gumby
# Scraping review page: https://www.commonsensemedia.org/tv-reviews/looney-tunes
# Data saved to detailed_reviews_with_ratings.json
